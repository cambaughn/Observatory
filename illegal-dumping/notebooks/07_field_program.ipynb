# %% [markdown]
# # 07 — Field Program (operational notebook)
#
# **This is not an analysis notebook.** It is the canonical field-day companion:
# site rationale, embedded maps, checklists, and space to type observations —
# built for a laptop or tablet while planning and running a field day.
# Quick phone reference: [`docs/field_program.md`](../docs/field_program.md).
# Selection methodology: notebook 06. Data: Jan–Jun 2026; no new analysis here.
#
# # Overview
#
# **Purpose of today's investigation:** ground-truth the data's picture of
# illegal dumping at three kinds of places — chronic hotspots, typical-Valley
# recurring sites, and clean comparison areas — and answer the standing
# tracker questions that only a site visit can (RT-01/02/03, RT-07/08/09).
# Success = better places understood and better questions asked, not
# maximum sites visited.
#
# Safety/etiquette: several sites are encampment-adjacent. Don't photograph
# people or tents up close; shoot the curb and context. If someone engages,
# lead with curiosity, not clipboard.
#
#
# ## Maps (open before you drive)
#
# Interactive HTML maps in [`field-notes/maps/`](../field-notes/maps/) — open
# locally in any browser, or AirDrop/email the files to your phone (each is
# <25 KB; tiles load from the network). Every marker popup includes an
# *Open in Google Maps* link for turn-by-turn.
#
# - **[Valley route](../field-notes/maps/valley_route.html)** — all 9 Valley
#   sites, numbered in visit order and connected
# - **[Koreatown pair](../field-notes/maps/koreatown.html)** — the two New
#   Hampshire sites with the 300m/800m migration-check rings
# - **[Citywide planning](../field-notes/maps/citywide.html)** — all top 10
#   sites, for planning future trips (not routing)
#
# Regenerate anytime: `python scripts/build_field_maps.py`
#
# ## Route overview
#
# **Route: Reseda → Encino → Van Nuys → Panorama City → NoHo NE → NoHo Arts
# → Studio City → Sherman Oaks.**
#
# Driving bonus, no stops needed: the **Van Nuys Blvd → Ventura Blvd
# gradient**. Between stops 5 → 8 and 8 → 9 you cross the sharpest demand
# boundary in the Valley (1.60x → 0.59x citywide mix). Note *where* the street
# character changes and whether it tracks the NC boundary.
#
# ## Suggested One-Day Itinerary
#
# **Morning (8:00–12:00) — West Valley + gradient**
# Crews clear piles during the day, so morning shows the truest accumulation.
# - 8:00 Reseda: Sherman Way pair (stops 1–2) — walk the block between them
# - 9:15 Encino: Yarmouth Ave pocket (stop 3)
# - 10:15 Van Nuys: Delano St (+ Erwin St if quick) (stop 4)
# - 11:15 Panorama City: Van Nuys Blvd (stop 5)
#
# **Afternoon (12:30–4:30) — East Valley + controls**
# - 12:30 NoHo NE: 13036 Sherman Way (stop 6), lunch on Lankershim
# - 1:45 NoHo: 5767 Lankershim (stop 7)
# - 2:45 Studio City: Arch Dr (stop 8), then drive Ventura Blvd west —
#   clean-control pass (Section C #1)
# - 3:45 Sherman Oaks: Addison St (stop 9); Ventura corridor pass (C #2)
#
# **Optional stops (energy permitting)**
# - **Koreatown pair over the hill** (~30 min from Sherman Oaks via 101):
#   4th & New Hampshire + 114 S New Hampshire (A #1 + #6) — the natural
#   experiment. Highest-value single detour available.
# - Woodland Hills–Warner Center commercial pass (C #3) — better saved for a
#   West Valley morning.
# - Encino's Newcastle/White Oak pockets if Yarmouth went quickly.

# %%
from pathlib import Path

import folium
import geopandas as gpd
import pandas as pd

program = pd.read_csv(Path("../data/processed/field_program_nb06.csv"))
A = program[program["section"] == "A_citywide"].reset_index(drop=True)
B = program[program["section"] == "B_valley"].reset_index(drop=True)
bounds = gpd.read_file("../../shared/datasets/raw/la_neighborhood_councils.geojson")
bounds["NAME"] = bounds["NAME"].str.upper().str.strip()

stacks = pd.read_csv(Path("../data/processed/field_area_stacks.csv"))
diags = pd.read_csv(Path("../data/processed/field_site_diagnostics.csv"))

ROUTE_ORDER = ["17808", "17900", "5130", "14102", "9404", "13036", "5767", "4176", "14359"]
routed = pd.concat([B[B["address"].str.startswith(n)] for n in ROUTE_ORDER]).reset_index(drop=True)

def gmaps(r):
    return f"https://www.google.com/maps/search/?api=1&query={r['lat']:.6f},{r['lon']:.6f}"

def popup(r, why_col="why_interesting"):
    return folium.Popup(
        f"<b>{r['address']}</b><br>{r['neighborhood']}<br>"
        f"reports: {r['reports']} | median gap: {r['median_gap_days']} d<br>"
        f"<i>{r[why_col]}</i><br><a href='{gmaps(r)}' target='_blank'>Open in Google Maps</a>",
        max_width=300)

def stop_map(row, others, zoom=16, color="royalblue"):
    """Mini map: current stop highlighted; ALL surrounding report-stacks
    within 350m shown as orange dots (area = the real unit of investigation;
    the pin is often just the modal reporting address)."""
    m = folium.Map(location=[row["lat"], row["lon"]], zoom_start=zoom, tiles="cartodbpositron")
    sid = diags.loc[diags["address"] == row["address"], "site_id"].iloc[0]
    area = stacks[stacks["site_id"] == sid]
    for _, a in area.iterrows():
        folium.CircleMarker([a["lat"], a["lon"]], radius=max(3, min(12, a["n_reports"] ** 0.5 * 2)),
                            color="darkorange", weight=1, fill=True, fill_opacity=0.5,
                            tooltip=f"{a['n_reports']} reports at this spot").add_to(m)
    for _, o in others.iterrows():
        if o["address"] != row["address"]:
            folium.CircleMarker([o["lat"], o["lon"]], radius=5, color="#999",
                                fill=True, fill_opacity=0.6, tooltip=o["address"]).add_to(m)
    folium.CircleMarker([row["lat"], row["lon"]], radius=12, color=color, weight=3,
                        fill=True, fill_opacity=0.75, popup=popup(row)).add_to(m)
    return m

print(f"{len(A)} citywide sites, {len(B)} Valley sites loaded")
# Out:
# 10 citywide sites, 9 Valley sites loaded

# %% [markdown]
# ## Interactive Valley map — all 9 sites in visit order

# %%
m = folium.Map(location=[34.19, -118.44], zoom_start=12, tiles="cartodbpositron")
folium.PolyLine(routed[["lat", "lon"]].values.tolist(), color="royalblue",
                weight=3, opacity=0.6, dash_array="6").add_to(m)
for i, r in routed.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=13, color="royalblue",
                        fill=True, fill_color="white", fill_opacity=1, popup=popup(r)).add_to(m)
    folium.map.Marker([r["lat"], r["lon"]], icon=folium.DivIcon(
        html=f"<div style='font-size:11px;font-weight:bold;color:royalblue;"
             f"text-align:center;width:26px;margin-left:-13px;margin-top:-7px'>{i+1}</div>")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_667f4223b45c5c4f454ca10e2eed43a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_667f4223b45c5c4f454ca10e2eed43a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_667f4223b45c5c4f454ca10e2eed43a5 = L.map(
#                 &quot;map_667f4223b45c5c4f454ca10e2eed43a5&quot;,
#                 {
#                     center: [34.19, -118.44],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a6f6068c3161642b8a238ba1061a5ba = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a6f6068c3161642b8a238ba1061a5ba.addTo(map_667f4223b45c5c4f454ca10e2eed43a5);
#
#
#             var poly_line_537a2b817a251ae5e1448edf16453367 = L.polyline(
#                 [[34.200306, -118.5212475], [34.200925052552805, -118.52286867799768], [34.163793, -118.519947], [34.18240717241379, -118.44053247413794], [34.240833, -118.449612], [34.20045, -118.41711750000002], [34.1756022, -118.38148822499998], [34.143093, -118.37226149999998], [34.161741, -118.4464665]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: &quot;6&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;royalblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_667f4223b45c5c4f454ca10e2eed43a5);
#
#
#             var circle_marker_cd2eb404039aa945dcb23ce6a7204136 = L.circleMarker(
#                 [34.200306, -118.5212475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_667f4223b45c5c4f454ca10e2eed43a5);
#
#
#         var popup_bd63dc429ca8664e451e1ef68c3fe359 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a9b565b1029a322eba69da53738735a1 = $(`&lt;div id=&quot;html_a9b565b1029a322eba69da53738735a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;17808 SHERMAN WAY, LOS ANGELES, CA, 91335&lt;/b&gt;&lt;br&gt;Reseda&lt;br&gt;reports: 53 | median gap: 2.8 d&lt;br&gt;&lt;i&gt;high-volume chronic site; Sherman Way corridor&lt;/i&gt;&lt;br&gt;&lt;a href=&#x27;https://www.google.com/maps/search/?api=1&amp;query=34.200306,-118.521248&#x27; target=&#x27;_blank&#x27;&gt;Open in Google Maps&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_bd63dc429ca8664e451e1ef68c3fe359.setContent(html_a9b565b1029a322eba69da53738735a1);
#
#
#
#         circle_marker_cd2eb404039aa945dcb23ce6a7204136.bindPopup(popup_bd63dc429ca8664e451e1ef68c3fe359)
#         ;
#
#
#
#
#             var marker_05aba0f3cf3e08ced92a745328ad900a = L.marker(
#                 [34.200306, -118.5212475],
#                 {
# }
#             ).addTo(map_667f4223b45c5c4f454ca10e2eed43a5);
#
#
#             var div_icon_03774d51202e174b3a71d84aa60864a6 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size:11px;font-weight:bold;color:royalblue;text-align:center;width:26px;margin-left:-13px;margin-top:-7px\u0027\u003e1\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_05aba0f3cf3e08ced92a745328ad900a.setIcon(div_icon_03774d51202e174b3a71d84aa60864a6);
#
#
#             var circle_marker_522fbb9c7ef0a6da0e4db9add2df6762 = L.circleMarker(
#                 [34.200925052552805, -118.52286867799768],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opaci

# %% [markdown]
# ## Interactive Citywide map — top 10 (trip planning, not routing)

# %%
m = folium.Map(location=[34.04, -118.32], zoom_start=11, tiles="cartodbpositron")
for _, r in A.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=9, color="crimson", weight=2,
                        fill=True, fill_opacity=0.85, popup=popup(r),
                        tooltip=r["address"]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac5bbd9169a165d880d5514f78c09b6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac5bbd9169a165d880d5514f78c09b6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac5bbd9169a165d880d5514f78c09b6a = L.map(
#                 &quot;map_ac5bbd9169a165d880d5514f78c09b6a&quot;,
#                 {
#                     center: [34.04, -118.32],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa1750193019336b2fdb3aa2683f0a90 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa1750193019336b2fdb3aa2683f0a90.addTo(map_ac5bbd9169a165d880d5514f78c09b6a);
#
#
#             var circle_marker_33e7aa0a81272f93a97de0fb1e5fa65b = L.circleMarker(
#                 [34.067372919723596, -118.29294677907863],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ac5bbd9169a165d880d5514f78c09b6a);
#
#
#         var popup_098b669897a605c7c20ca031bd3e77fd = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b8874b4a84d81df8e301cf8e9af5c616 = $(`&lt;div id=&quot;html_b8874b4a84d81df8e301cf8e9af5c616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;4TH ST and NEW HAMPSHIRE AVE&lt;/b&gt;&lt;br&gt;WILSHIRE CENTER - KOREATOWN NC&lt;br&gt;reports: 115 | median gap: 0.4 d&lt;br&gt;&lt;i&gt;WENT QUIET Apr 17 after heavy activity - intervention?; encampment-adjacent (LSD); sub-daily report gaps&lt;/i&gt;&lt;br&gt;&lt;a href=&#x27;https://www.google.com/maps/search/?api=1&amp;query=34.067373,-118.292947&#x27; target=&#x27;_blank&#x27;&gt;Open in Google Maps&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_098b669897a605c7c20ca031bd3e77fd.setContent(html_b8874b4a84d81df8e301cf8e9af5c616);
#
#
#
#         circle_marker_33e7aa0a81272f93a97de0fb1e5fa65b.bindPopup(popup_098b669897a605c7c20ca031bd3e77fd)
#         ;
#
#
#
#
#             circle_marker_33e7aa0a81272f93a97de0fb1e5fa65b.bindTooltip(
#                 `&lt;div&gt;
#                      4TH ST and NEW HAMPSHIRE AVE
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a6aed51b142f912cde4cc638087b5a67 = L.circleMarker(
#                 [34.078887, -118.22247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ac5bbd9169a165d880d5514f78c09b6a);
#
#
#         var popup_845682a089af0ef3f15e3e64783f43f9 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1f447749e7ffb6c929be0168214dbecc = $(`&lt;div id=&quot;html_1f447749e7ffb6c929be0168214dbecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;350 N AVENUE 21, LOS ANGELES, CA, 90031&lt;/b&gt;&lt;br&gt;LINCOLN HEIGHTS NC&lt;br&gt;reports: 78 | median gap: 1.0 d&lt;br&gt;&lt;i&gt;encampment-adjacent (LSD); refills every 1-2 days&lt;/i&gt;&lt;br&gt;&lt;a href=&#x27;https://www.google.com/maps/search/?api=1&amp;query=34.078887,-118.222470&#x27; target=&#x27;_blank&#x27;&gt;Open in Google Maps&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_845682a089af0ef3f15e3e64783f43f9.setContent(html_1f447749e7ffb6c929be0168214dbecc);
#
#
#
#         circle_marker_a6aed51b142f912cde4cc638087b5a67.bindPopup(popup_845682a089af0ef3f15e3e64783f43f9)
#         ;
#
#
#
#
#             circle_marker_a6aed51b142f912cde4cc638087b5a67.bindTooltip(
#                 `&lt;div&gt;
#                      350 N AVENUE 21, LOS ANGELES, CA, 90031
#                  &lt;/div&gt;`,

# %% [markdown]
# ## Interactive Koreatown map — the New Hampshire pair

# %%
pair = A[A["address"].str.contains("NEW HAMPSHIRE")]
quiet = pair[pair["why_interesting"].str.contains("QUIET")].iloc[0]
active = pair[~pair["why_interesting"].str.contains("QUIET")].iloc[0]
m = folium.Map(location=[(quiet["lat"] + active["lat"]) / 2,
                         (quiet["lon"] + active["lon"]) / 2],
               zoom_start=16, tiles="cartodbpositron")
for r, color, label in [(quiet, "gray", "WENT QUIET Apr 17 - what changed?"),
                        (active, "crimson", "still active - the control")]:
    folium.CircleMarker([r["lat"], r["lon"]], radius=12, color=color, weight=3,
                        fill=True, fill_opacity=0.7, popup=popup(r),
                        tooltip=f"{r['address']} - {label}").add_to(m)
for radius, dash in [(300, None), (800, "8")]:
    folium.Circle([quiet["lat"], quiet["lon"]], radius=radius, color="#888", weight=1.5,
                  fill=False, dash_array=dash,
                  tooltip=f"{radius}m ring (dumping stayed flat here after the site went quiet)").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1b7deb9daf04bfc1f8251b66f17b7e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1b7deb9daf04bfc1f8251b66f17b7e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1b7deb9daf04bfc1f8251b66f17b7e0 = L.map(
#                 &quot;map_e1b7deb9daf04bfc1f8251b66f17b7e0&quot;,
#                 {
#                     center: [34.06981524753303, -118.29273682104616],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2818d6e784ac85deddc8829b0b2c6e35 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2818d6e784ac85deddc8829b0b2c6e35.addTo(map_e1b7deb9daf04bfc1f8251b66f17b7e0);
#
#
#             var circle_marker_d92832b09d35f143c3eb740e3e0d07de = L.circleMarker(
#                 [34.067372919723596, -118.29294677907863],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1b7deb9daf04bfc1f8251b66f17b7e0);
#
#
#         var popup_b15d150c89088bd0cd6fb7da9eddffe9 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7c6709ec11bcbc63a4fa0c7bcec6da81 = $(`&lt;div id=&quot;html_7c6709ec11bcbc63a4fa0c7bcec6da81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;4TH ST and NEW HAMPSHIRE AVE&lt;/b&gt;&lt;br&gt;WILSHIRE CENTER - KOREATOWN NC&lt;br&gt;reports: 115 | median gap: 0.4 d&lt;br&gt;&lt;i&gt;WENT QUIET Apr 17 after heavy activity - intervention?; encampment-adjacent (LSD); sub-daily report gaps&lt;/i&gt;&lt;br&gt;&lt;a href=&#x27;https://www.google.com/maps/search/?api=1&amp;query=34.067373,-118.292947&#x27; target=&#x27;_blank&#x27;&gt;Open in Google Maps&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_b15d150c89088bd0cd6fb7da9eddffe9.setContent(html_7c6709ec11bcbc63a4fa0c7bcec6da81);
#
#
#
#         circle_marker_d92832b09d35f143c3eb740e3e0d07de.bindPopup(popup_b15d150c89088bd0cd6fb7da9eddffe9)
#         ;
#
#
#
#
#             circle_marker_d92832b09d35f143c3eb740e3e0d07de.bindTooltip(
#                 `&lt;div&gt;
#                      4TH ST and NEW HAMPSHIRE AVE - WENT QUIET Apr 17 - what changed?
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5ffa0fdb4c4d625b23736030e294743d = L.circleMarker(
#                 [34.07225757534246, -118.2925268630137],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1b7deb9daf04bfc1f8251b66f17b7e0);
#
#
#         var popup_6b2e5994919c5ed15e898fcab8ae8d90 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_bd0ff4e1e6cc4085b1dd032f2695957a = $(`&lt;div id=&quot;html_bd0ff4e1e6cc4085b1dd032f2695957a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;114 S NEW HAMPSHIRE AVE, LOS ANGELES, CA, 90004&lt;/b&gt;&lt;br&gt;WILSHIRE CENTER - KOREATOWN NC&lt;br&gt;reports: 73 | median gap: 0.9 d&lt;br&gt;&lt;i&gt;sub-daily report gaps&lt;/i&gt;&lt;br&gt;&lt;a href=&#x27;https://www.google.com/maps/search/?api=1&amp;query=34.072258,-118.292527&#x27; target=&#x27;_blank&#x27;&gt;Open in Google Maps&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_6b2e5994919c5ed15e898fcab8ae8d90.setContent(html_bd0ff4e1e6cc4085b1dd032f2695957a);
#
#
#
#         circle_marker_5ffa0fdb4c4d625b23736030e294743d.bindPopup(popup_6b2e5994919c5ed15e898fcab8ae8d90)
#         ;
#
#
#
#
#             circle_marker_5ffa0fdb4c4d625b23736030e294743d.bindTooltip(
#                 `&lt;div&gt;
#                      114 S NEW HAMPS

# %% [markdown]
# ---
#
# # Valley Stops
#
# In visit order (matches the route map numbering).
#
# **How to read the pins (important):** forensic check of these sites found
# most are *single-address stacks* — every report geocoded to one exact
# coordinate, usually ~100% self-service. The pin marks the address people
# use when reporting, not necessarily the exact curb; the surrounding block
# typically carries 5–10x more reports across dozens of spots (orange dots
# on each stop map). **Investigate the area, not just the address** — and at
# single-stack sites, consider who the repeat reporter might be (a doorbell
# conversation could resolve the chronic-reporter question, RT-11).

# %% [markdown]
# ## B1. **17808 Sherman Way, Reseda** (53 · ~2.8d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.200306,-118.521248)
#
# **Why we're here:** start of the corridor pair. Walk east from here.
#
# **Known findings (from the data):** 53 reports Jan–Jun · median gap 2.8 d · LSD-serviced 0% · gone-on-arrival 28% · neighborhood: Reseda
#
# **Immediate area (drive/walk the block):** 271 more reports at 62 other spots within 250m — this pin is only ~16% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("17808")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43d1e85305499226f8c070542d30e6ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43d1e85305499226f8c070542d30e6ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43d1e85305499226f8c070542d30e6ef = L.map(
#                 &quot;map_43d1e85305499226f8c070542d30e6ef&quot;,
#                 {
#                     center: [34.200306, -118.5212475],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f300d0863c571e12857faebb402a87f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f300d0863c571e12857faebb402a87f.addTo(map_43d1e85305499226f8c070542d30e6ef);
#
#
#             var circle_marker_51bee95f3f4cb3c2328cee1d2a16c186 = L.circleMarker(
#                 [34.197669, -118.519474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_43d1e85305499226f8c070542d30e6ef);
#
#
#             circle_marker_51bee95f3f4cb3c2328cee1d2a16c186.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9bafc74ffd0b0163454706888943253e = L.circleMarker(
#                 [34.198533, -118.52411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_43d1e85305499226f8c070542d30e6ef);
#
#
#             circle_marker_9bafc74ffd0b0163454706888943253e.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6dca069ede2ad197ef8085792507c121 = L.circleMarker(
#                 [34.198533, -118.518304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.4641016151377544, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_43d1e85305499226f8c070542d30e6ef);
#
#
#             circle_marker_6dca069ede2ad197ef8085792507c121.bindTooltip(
#                 `&lt;div&gt;
#                      3 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2b1dee0d113381b390b96ddec144e034 = L.circleMarker(
#                 [34.198695, -118.518934],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.656854249492381, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_43d1e85305499226f8c070542d30e6ef);
#
#
#             circle_marker_2b1dee0d113381b390b96ddec144e034.bindTooltip(
#                 `&lt;div&gt;
#                      8 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B2. **17900 Sherman Way, Reseda** (78 · ~1.3d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.200925,-118.522869)
#
# **Why we're here:** 90m away. Key question: one continuous condition or two distinct spots? What's between them?
#
# **Known findings (from the data):** 78 reports Jan–Jun · median gap 1.3 d · LSD-serviced 27% · gone-on-arrival 27% · neighborhood: Reseda
#
# **Immediate area (drive/walk the block):** 394 more reports at 55 other spots within 250m — this pin is only ~13% of local activity. Pin type: 5 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("17900")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1a5e0df77c3c2a9eb4d10f23f4cf02c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1a5e0df77c3c2a9eb4d10f23f4cf02c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1a5e0df77c3c2a9eb4d10f23f4cf02c = L.map(
#                 &quot;map_b1a5e0df77c3c2a9eb4d10f23f4cf02c&quot;,
#                 {
#                     center: [34.200925052552805, -118.52286867799768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58e5d48004759bfe9095a72e071ec018 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58e5d48004759bfe9095a72e071ec018.addTo(map_b1a5e0df77c3c2a9eb4d10f23f4cf02c);
#
#
#             var circle_marker_7bcc248405d72e86966f3351d016d45b = L.circleMarker(
#                 [34.198011, -118.52411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b1a5e0df77c3c2a9eb4d10f23f4cf02c);
#
#
#             circle_marker_7bcc248405d72e86966f3351d016d45b.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c6efcaad5598bf694855759bcf83bb70 = L.circleMarker(
#                 [34.198182, -118.524146],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b1a5e0df77c3c2a9eb4d10f23f4cf02c);
#
#
#             circle_marker_c6efcaad5598bf694855759bcf83bb70.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fec9c1794bcc5a33ed66e845900405f3 = L.circleMarker(
#                 [34.198533, -118.52411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b1a5e0df77c3c2a9eb4d10f23f4cf02c);
#
#
#             circle_marker_fec9c1794bcc5a33ed66e845900405f3.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_33000ef6c3a53a63ea7fa73ad7d06953 = L.circleMarker(
#                 [34.19883, -118.523205],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b1a5e0df77c3c2a9eb4d10f23f4cf02c);
#
#
#             circle_marker_33000ef6c3a53a63ea7fa73ad7d06953.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_mar

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B3. **5130 Yarmouth Ave, Encino** (37 · ~3.5d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.163793,-118.519947)
#
# **Why we're here:** *chronic pocket inside a clean neighborhood.* Just off the Ventura corridor. Why THIS street? (Newcastle Ave & White Oak Ave pockets are 1–2 blocks over if time allows.)
#
# **Known findings (from the data):** 37 reports Jan–Jun · median gap 3.5 d · LSD-serviced 0% · gone-on-arrival 16% · neighborhood: Encino
#
# **Immediate area (drive/walk the block):** 211 more reports at 36 other spots within 250m — this pin is only ~15% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("5130")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f77104bab6c93189848b5e938b26aec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f77104bab6c93189848b5e938b26aec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f77104bab6c93189848b5e938b26aec = L.map(
#                 &quot;map_1f77104bab6c93189848b5e938b26aec&quot;,
#                 {
#                     center: [34.163793, -118.519947],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07a5fa6ae9de95260907a7ccfc129780 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07a5fa6ae9de95260907a7ccfc129780.addTo(map_1f77104bab6c93189848b5e938b26aec);
#
#
#             var circle_marker_a8064f11432640622162e856995b2c9f = L.circleMarker(
#                 [34.161417, -118.518044],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f77104bab6c93189848b5e938b26aec);
#
#
#             circle_marker_a8064f11432640622162e856995b2c9f.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_be6dc3c10ca1e3f6a6c4c680ec87070f = L.circleMarker(
#                 [34.16202, -118.518098],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f77104bab6c93189848b5e938b26aec);
#
#
#             circle_marker_be6dc3c10ca1e3f6a6c4c680ec87070f.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_42fb0a416106147c1f9166e9c4a0237d = L.circleMarker(
#                 [34.16211, -118.518134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.898979485566356, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f77104bab6c93189848b5e938b26aec);
#
#
#             circle_marker_42fb0a416106147c1f9166e9c4a0237d.bindTooltip(
#                 `&lt;div&gt;
#                      6 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_840013f3e2456a219de9619bdbc0e63c = L.circleMarker(
#                 [34.162137, -118.518372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f77104bab6c93189848b5e938b26aec);
#
#
#             circle_marker_840013f3e2456a219de9619bdbc0e63c.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_mar

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B4. **14102 Delano St, Van Nuys** (58 · ~2.1d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.182407,-118.440532)
#
# **Why we're here:** the Valley dumping capital's top site; 31% gone-on-arrival. Erwin St (41 reports) is 3 blocks south if time allows.
#
# **Known findings (from the data):** 58 reports Jan–Jun · median gap 2.1 d · LSD-serviced 0% · gone-on-arrival 31% · neighborhood: Van Nuys
#
# **Immediate area (drive/walk the block):** 433 more reports at 130 other spots within 250m — this pin is only ~4% of local activity. Pin type: 3 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("14102")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ab012b9ff20de46c6ddcd9158ddf297 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ab012b9ff20de46c6ddcd9158ddf297&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ab012b9ff20de46c6ddcd9158ddf297 = L.map(
#                 &quot;map_5ab012b9ff20de46c6ddcd9158ddf297&quot;,
#                 {
#                     center: [34.18240717241379, -118.44053247413794],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb5a65e53ff4d17c66475937854c15a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb5a65e53ff4d17c66475937854c15a.addTo(map_5ab012b9ff20de46c6ddcd9158ddf297);
#
#
#             var circle_marker_3e945e97cac47150c1185461a1919274 = L.circleMarker(
#                 [34.179395, -118.439977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_5ab012b9ff20de46c6ddcd9158ddf297);
#
#
#             circle_marker_3e945e97cac47150c1185461a1919274.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_eeaac1e30ba52f670456a0ad84f4e061 = L.circleMarker(
#                 [34.179408, -118.439992],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_5ab012b9ff20de46c6ddcd9158ddf297);
#
#
#             circle_marker_eeaac1e30ba52f670456a0ad84f4e061.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_83f0c60ea39a4bf27c917ecb4c052ca7 = L.circleMarker(
#                 [34.179534, -118.4391],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_5ab012b9ff20de46c6ddcd9158ddf297);
#
#
#             circle_marker_83f0c60ea39a4bf27c917ecb4c052ca7.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f864bafaad5ae42c548a673fdf39a41a = L.circleMarker(
#                 [34.179759, -118.438564],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.47213595499958, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_5ab012b9ff20de46c6ddcd9158ddf297);
#
#
#             circle_marker_f864bafaad5ae42c548a673fdf39a41a.bindTooltip(
#                 `&lt;div&gt;
#                      5 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B5. **9404 Van Nuys Blvd, Panorama City** (35 · ~5.5d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.240833,-118.449612)
#
# **Why we're here:** the *gone-on-arrival anomaly* area: reports here more often end with nothing collected, and closures are slowest. Does the street look scavenged?
#
# **Known findings (from the data):** 35 reports Jan–Jun · median gap 5.5 d · LSD-serviced 0% · gone-on-arrival 23% · neighborhood: Panorama City
#
# **Immediate area (drive/walk the block):** 180 more reports at 53 other spots within 250m — this pin is only ~16% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("9404")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8df84859a821cb841fdc2017c332feda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8df84859a821cb841fdc2017c332feda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8df84859a821cb841fdc2017c332feda = L.map(
#                 &quot;map_8df84859a821cb841fdc2017c332feda&quot;,
#                 {
#                     center: [34.240833, -118.449612],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aebf92041d166e49948b60e53c26ef87 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aebf92041d166e49948b60e53c26ef87.addTo(map_8df84859a821cb841fdc2017c332feda);
#
#
#             var circle_marker_dd67abe6176dfb44e5da0661ae150ca9 = L.circleMarker(
#                 [34.237692, -118.449711],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.47213595499958, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8df84859a821cb841fdc2017c332feda);
#
#
#             circle_marker_dd67abe6176dfb44e5da0661ae150ca9.bindTooltip(
#                 `&lt;div&gt;
#                      5 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_170484c215872c02b783533376a7e8fd = L.circleMarker(
#                 [34.237935, -118.44833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.291502622129181, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8df84859a821cb841fdc2017c332feda);
#
#
#             circle_marker_170484c215872c02b783533376a7e8fd.bindTooltip(
#                 `&lt;div&gt;
#                      7 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_520c52738f2abe4857ab6a920f2447f0 = L.circleMarker(
#                 [34.237989, -118.449756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8df84859a821cb841fdc2017c332feda);
#
#
#             circle_marker_520c52738f2abe4857ab6a920f2447f0.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7f763fff966d4512b87f1a176f0c0dcb = L.circleMarker(
#                 [34.238088, -118.450485],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8df84859a821cb841fdc2017c332feda);
#
#
#             circle_marker_7f763fff966d4512b87f1a176f0c0dcb.bindTooltip(
#                 `&lt;div&gt;
#                      4 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B6. **13036 Sherman Way, North Hollywood (91605)** (46 · ~2.5d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.200450,-118.417118)
#
# **Why we're here:** encampment-adjacent (LSD), eastern Sherman Way. Compare with the Reseda end of the same street from stop 1–2.
#
# **Known findings (from the data):** 46 reports Jan–Jun · median gap 2.5 d · LSD-serviced 100% · gone-on-arrival 20% · neighborhood: North Hollywood
#
# **Immediate area (drive/walk the block):** 68 more reports at 25 other spots within 250m — this pin is only ~40% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("13036")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de23c049d3c6ac098e1cb3cae727b901 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de23c049d3c6ac098e1cb3cae727b901&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de23c049d3c6ac098e1cb3cae727b901 = L.map(
#                 &quot;map_de23c049d3c6ac098e1cb3cae727b901&quot;,
#                 {
#                     center: [34.20045, -118.41711750000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30a64fccd27e94c9809ae8c080c19306 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30a64fccd27e94c9809ae8c080c19306.addTo(map_de23c049d3c6ac098e1cb3cae727b901);
#
#
#             var circle_marker_04879af92abb010963468280b0277c75 = L.circleMarker(
#                 [34.19829, -118.414732],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_de23c049d3c6ac098e1cb3cae727b901);
#
#
#             circle_marker_04879af92abb010963468280b0277c75.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_dd33bc8aefca276afe9be655c6de6548 = L.circleMarker(
#                 [34.198632, -118.41467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_de23c049d3c6ac098e1cb3cae727b901);
#
#
#             circle_marker_dd33bc8aefca276afe9be655c6de6548.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_77bddbbec003641615db65cf7de53ebe = L.circleMarker(
#                 [34.198695, -118.415241],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.4641016151377544, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_de23c049d3c6ac098e1cb3cae727b901);
#
#
#             circle_marker_77bddbbec003641615db65cf7de53ebe.bindTooltip(
#                 `&lt;div&gt;
#                      3 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_eb1eacabe70517912681066204c6e8a0 = L.circleMarker(
#                 [34.198731, -118.414202],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_de23c049d3c6ac098e1cb3cae727b901);
#
#
#             circle_marker_eb1eacabe70517912681066204c6e8a0.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var ci

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B7. **5767 Lankershim Blvd, NoHo** (60 · ~1.6d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.175602,-118.381488)
#
# **Why we're here:** encampment-adjacent archetype on the NoHo spine.
#
# **Known findings (from the data):** 60 reports Jan–Jun · median gap 1.6 d · LSD-serviced 100% · gone-on-arrival 12% · neighborhood: North Hollywood
#
# **Immediate area (drive/walk the block):** 408 more reports at 106 other spots within 250m — this pin is only ~13% of local activity. Pin type: 2 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("5767")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9181a527d3cee9482c2f316236199272 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9181a527d3cee9482c2f316236199272&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9181a527d3cee9482c2f316236199272 = L.map(
#                 &quot;map_9181a527d3cee9482c2f316236199272&quot;,
#                 {
#                     center: [34.1756022, -118.38148822499998],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6748bd926393239352639baeecfe1fac = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6748bd926393239352639baeecfe1fac.addTo(map_9181a527d3cee9482c2f316236199272);
#
#
#             var circle_marker_49ddc010007a84ba8ac5c306eed414ac = L.circleMarker(
#                 [34.172955, -118.38141],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9181a527d3cee9482c2f316236199272);
#
#
#             circle_marker_49ddc010007a84ba8ac5c306eed414ac.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1f608415c913428ee58a7aa92c01f3b3 = L.circleMarker(
#                 [34.172964, -118.38195],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9181a527d3cee9482c2f316236199272);
#
#
#             circle_marker_1f608415c913428ee58a7aa92c01f3b3.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_cfc68da95fa92db68b891ffa8ece2712 = L.circleMarker(
#                 [34.17309, -118.380658],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9181a527d3cee9482c2f316236199272);
#
#
#             circle_marker_cfc68da95fa92db68b891ffa8ece2712.bindTooltip(
#                 `&lt;div&gt;
#                      9 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_42eb773cf1fb0f9f83821be4fb2b6e48 = L.circleMarker(
#                 [34.173117, -118.383214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9181a527d3cee9482c2f316236199272);
#
#
#             circle_marker_42eb773cf1fb0f9f83821be4fb2b6e48.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_bc

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B8. **4176 Arch Dr, Studio City** (22 · ~6.3d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.143093,-118.372261)
#
# **Why we're here:** *the clean-area ceiling.* This is as bad as Studio City gets. Calibrate: how does the worst spot in a clean neighborhood compare to an average Van Nuys corner?
#
# **Known findings (from the data):** 22 reports Jan–Jun · median gap 6.3 d · LSD-serviced 0% · gone-on-arrival 14% · neighborhood: Studio City
#
# **Immediate area (drive/walk the block):** 191 more reports at 51 other spots within 250m — this pin is only ~10% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("4176")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_493c754120a1e4a946c3e132a4682fed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_493c754120a1e4a946c3e132a4682fed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_493c754120a1e4a946c3e132a4682fed = L.map(
#                 &quot;map_493c754120a1e4a946c3e132a4682fed&quot;,
#                 {
#                     center: [34.143093, -118.37226149999998],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e12509bfd627ccc31543c8f6ea62e9f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e12509bfd627ccc31543c8f6ea62e9f.addTo(map_493c754120a1e4a946c3e132a4682fed);
#
#
#             var circle_marker_8a422943d795e9e3403fb327bbffff66 = L.circleMarker(
#                 [34.140375, -118.371897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_493c754120a1e4a946c3e132a4682fed);
#
#
#             circle_marker_8a422943d795e9e3403fb327bbffff66.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_96bbb28899096084c202ff1224820859 = L.circleMarker(
#                 [34.140537, -118.370961],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_493c754120a1e4a946c3e132a4682fed);
#
#
#             circle_marker_96bbb28899096084c202ff1224820859.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1e1181f697d975f8001ff04d1c12ff09 = L.circleMarker(
#                 [34.140708, -118.372959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_493c754120a1e4a946c3e132a4682fed);
#
#
#             circle_marker_1e1181f697d975f8001ff04d1c12ff09.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_91d666d2291e65bdeedc5598745fd887 = L.circleMarker(
#                 [34.140924, -118.373152],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.656854249492381, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_493c754120a1e4a946c3e132a4682fed);
#
#
#             circle_marker_91d666d2291e65bdeedc5598745fd887.bindTooltip(
#                 `&lt;div&gt;
#                      8 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## B9. **14359 Addison St, Sherman Oaks** (26 · ~3.4d)
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.161741,-118.446466)
#
# **Why we're here:** moderate-area top site; end of loop.
#
# **Known findings (from the data):** 26 reports Jan–Jun · median gap 3.4 d · LSD-serviced 0% · gone-on-arrival 19% · neighborhood: Sherman Oaks
#
# **Immediate area (drive/walk the block):** 158 more reports at 31 other spots within 250m — this pin is only ~14% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(B[B["address"].str.startswith("14359")].iloc[0], B)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c65a459f88bf79cde1b27c3ad82bff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c65a459f88bf79cde1b27c3ad82bff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94c65a459f88bf79cde1b27c3ad82bff = L.map(
#                 &quot;map_94c65a459f88bf79cde1b27c3ad82bff&quot;,
#                 {
#                     center: [34.161741, -118.4464665],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ca9400be3de7c4c57996c18c148fc00 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ca9400be3de7c4c57996c18c148fc00.addTo(map_94c65a459f88bf79cde1b27c3ad82bff);
#
#
#             var circle_marker_30aba97e4a10f4fc693e242e34161208 = L.circleMarker(
#                 [34.158834, -118.44572],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_94c65a459f88bf79cde1b27c3ad82bff);
#
#
#             circle_marker_30aba97e4a10f4fc693e242e34161208.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_946c5691466c57b4a27c8408027b1f92 = L.circleMarker(
#                 [34.159221, -118.44499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_94c65a459f88bf79cde1b27c3ad82bff);
#
#
#             circle_marker_946c5691466c57b4a27c8408027b1f92.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4cc6c91446592ac49af087cdd0f121c1 = L.circleMarker(
#                 [34.159248, -118.445184],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_94c65a459f88bf79cde1b27c3ad82bff);
#
#
#             circle_marker_4cc6c91446592ac49af087cdd0f121c1.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b6ec6f5c6b080d7da10d3e42c7d7fe79 = L.circleMarker(
#                 [34.159417, -118.445423],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_94c65a459f88bf79cde1b27c3ad82bff);
#
#
#             circle_marker_b6ec6f5c6b080d7da10d3e42c7d7fe79.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_08fc4513313

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ---
#
# # Citywide Stops

# %% [markdown]
# ## A1. **4th St & New Hampshire Ave — Koreatown** · 115 reports · every ~0.4 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.067373,-118.292947)
#
# **Why we're here:** **THE headline site.** Citywide #1, fully encampment-serviced (LSD), reported ~daily for 3.5 months — then **silent since Apr 17**. Encampment at the vacant SE-corner lot was resolved in late April. Look for: what changed? Fencing? Cleared lot? Is the street actually clean? (RT-01/02/03)
#
# **Known findings (from the data):** 115 reports Jan–Jun · median gap 0.4 d · LSD-serviced 100% · gone-on-arrival 12% · neighborhood: WILSHIRE CENTER - KOREATOWN NC
#
# **Immediate area (drive/walk the block):** 327 more reports at 105 other spots within 250m — this pin is only ~26% of local activity. Pin type: 3 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?
# - Related tracker/findings: RT-01

# %%
stop_map(A.iloc[0], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11475a973590801b4b4125faabf5127a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11475a973590801b4b4125faabf5127a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11475a973590801b4b4125faabf5127a = L.map(
#                 &quot;map_11475a973590801b4b4125faabf5127a&quot;,
#                 {
#                     center: [34.067372919723596, -118.29294677907863],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60a141972342d41fce5820f898e50711 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60a141972342d41fce5820f898e50711.addTo(map_11475a973590801b4b4125faabf5127a);
#
#
#             var circle_marker_cfee34034812f12198626f0f80119e56 = L.circleMarker(
#                 [34.064613, -118.293453],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_11475a973590801b4b4125faabf5127a);
#
#
#             circle_marker_cfee34034812f12198626f0f80119e56.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_614be35bd723f82161c724c35f80b710 = L.circleMarker(
#                 [34.064694, -118.292814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.656854249492381, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_11475a973590801b4b4125faabf5127a);
#
#
#             circle_marker_614be35bd723f82161c724c35f80b710.bindTooltip(
#                 `&lt;div&gt;
#                      8 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_18a7a77930f1c5143508b60b0a0faea3 = L.circleMarker(
#                 [34.064775, -118.294632],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.47213595499958, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_11475a973590801b4b4125faabf5127a);
#
#
#             circle_marker_18a7a77930f1c5143508b60b0a0faea3.bindTooltip(
#                 `&lt;div&gt;
#                      5 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f2e7cab1c5a1b41d2940c82c297daa68 = L.circleMarker(
#                 [34.064829, -118.292702],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_11475a973590801b4b4125faabf5127a);
#
#
#             circle_marker_f2e7cab1c5a1b41d2940c82c297daa68.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A2. **350 N Avenue 21 — Lincoln Heights** · 78 · ~1.0 day
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.078887,-118.222470)
#
# **Why we're here:** Encampment-adjacent (LSD), refills daily, near river/rail. 0% gone-on-arrival — piles always there when crews arrive.
#
# **Known findings (from the data):** 78 reports Jan–Jun · median gap 1.0 d · LSD-serviced 100% · gone-on-arrival 0% · neighborhood: LINCOLN HEIGHTS NC
#
# **Immediate area (drive/walk the block):** 56 more reports at 19 other spots within 250m — this pin is only ~58% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[1], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70a6abd11bdbbed185522a45d1989927 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70a6abd11bdbbed185522a45d1989927&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70a6abd11bdbbed185522a45d1989927 = L.map(
#                 &quot;map_70a6abd11bdbbed185522a45d1989927&quot;,
#                 {
#                     center: [34.078887, -118.22247],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fd70ab2416585f43c4bd100c61f9123 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fd70ab2416585f43c4bd100c61f9123.addTo(map_70a6abd11bdbbed185522a45d1989927);
#
#
#             var circle_marker_d396d242a04855729c582dd89610c29a = L.circleMarker(
#                 [34.075872, -118.222452],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_70a6abd11bdbbed185522a45d1989927);
#
#
#             circle_marker_d396d242a04855729c582dd89610c29a.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4a318a0653ab87f9cd40c0b1443eb9f7 = L.circleMarker(
#                 [34.075917, -118.222466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_70a6abd11bdbbed185522a45d1989927);
#
#
#             circle_marker_4a318a0653ab87f9cd40c0b1443eb9f7.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_38294691b0d4b49d8feb6f12ac95d5f2 = L.circleMarker(
#                 [34.076034, -118.222538],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_70a6abd11bdbbed185522a45d1989927);
#
#
#             circle_marker_38294691b0d4b49d8feb6f12ac95d5f2.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_975140fc0e41860308d673e1ff219200 = L.circleMarker(
#                 [34.076052, -118.221921],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_70a6abd11bdbbed185522a45d1989927);
#
#
#             circle_marker_975140fc0e41860308d673e1ff219200.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ce05a6f0038

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A3. **17900 Sherman Way — Reseda** · 78 · ~1.3 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.200925,-118.522869)
#
# **Why we're here:** Valley anchor of the Sherman Way corridor (see Route). Mixed servicing (27% LSD), 27% gone-on-arrival.
#
# **Known findings (from the data):** 78 reports Jan–Jun · median gap 1.3 d · LSD-serviced 27% · gone-on-arrival 27% · neighborhood: RESEDA NC
#
# **Immediate area (drive/walk the block):** 394 more reports at 55 other spots within 250m — this pin is only ~13% of local activity. Pin type: 5 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[2], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df58d1b792cbf003167d7d8c9b572d09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df58d1b792cbf003167d7d8c9b572d09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df58d1b792cbf003167d7d8c9b572d09 = L.map(
#                 &quot;map_df58d1b792cbf003167d7d8c9b572d09&quot;,
#                 {
#                     center: [34.200925052552805, -118.52286867799768],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a807171e1c89587f63bf59f385d9b977 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a807171e1c89587f63bf59f385d9b977.addTo(map_df58d1b792cbf003167d7d8c9b572d09);
#
#
#             var circle_marker_5b717024e3b0da4a733ba3465ab1ed05 = L.circleMarker(
#                 [34.198011, -118.52411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_df58d1b792cbf003167d7d8c9b572d09);
#
#
#             circle_marker_5b717024e3b0da4a733ba3465ab1ed05.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_930caf21dcc48f339bd3d4ad9a7e38b7 = L.circleMarker(
#                 [34.198182, -118.524146],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_df58d1b792cbf003167d7d8c9b572d09);
#
#
#             circle_marker_930caf21dcc48f339bd3d4ad9a7e38b7.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d7d959c731eb3fc15423c59f20cd683c = L.circleMarker(
#                 [34.198533, -118.52411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_df58d1b792cbf003167d7d8c9b572d09);
#
#
#             circle_marker_d7d959c731eb3fc15423c59f20cd683c.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a4eedc60051b3c0abc8bbe264c27a1e7 = L.circleMarker(
#                 [34.19883, -118.523205],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_df58d1b792cbf003167d7d8c9b572d09);
#
#
#             circle_marker_a4eedc60051b3c0abc8bbe264c27a1e7.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_mar

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A4. **8142 Pershing Dr — Westchester/Playa** · 76 · same-day gaps
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=33.959027,-118.443930)
#
# **Why we're here:** The oddball: 76 reports in a *low-dumping district*, burst re-reporting (median gap 0 days). One angry building? One chronic pile? Worth solving.
#
# **Known findings (from the data):** 76 reports Jan–Jun · median gap 0.0 d · LSD-serviced 0% · gone-on-arrival 18% · neighborhood: WESTCHESTER/PLAYA NC
#
# **Immediate area (drive/walk the block):** 110 more reports at 49 other spots within 250m — this pin is only ~8% of local activity. Pin type: 4 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[3], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f8c1f879a323b4a4aa50fa230dc1f21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f8c1f879a323b4a4aa50fa230dc1f21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f8c1f879a323b4a4aa50fa230dc1f21 = L.map(
#                 &quot;map_1f8c1f879a323b4a4aa50fa230dc1f21&quot;,
#                 {
#                     center: [33.95902725, -118.44392956578947],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2809a06e45bd24a52a72fecc643d57e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2809a06e45bd24a52a72fecc643d57e.addTo(map_1f8c1f879a323b4a4aa50fa230dc1f21);
#
#
#             var circle_marker_8340a09c527be6b0b5dff7b85d80e36d = L.circleMarker(
#                 [33.956154, -118.44279],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f8c1f879a323b4a4aa50fa230dc1f21);
#
#
#             circle_marker_8340a09c527be6b0b5dff7b85d80e36d.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_12e33fd658e4b3bc108baf77f26ca4fa = L.circleMarker(
#                 [33.956505, -118.443213],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f8c1f879a323b4a4aa50fa230dc1f21);
#
#
#             circle_marker_12e33fd658e4b3bc108baf77f26ca4fa.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3c2e558c0ef1a29f56b8d404fc5bd454 = L.circleMarker(
#                 [33.956631, -118.445364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f8c1f879a323b4a4aa50fa230dc1f21);
#
#
#             circle_marker_3c2e558c0ef1a29f56b8d404fc5bd454.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d9c9b0391441d5852e9208fc089692f9 = L.circleMarker(
#                 [33.956784, -118.441791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1f8c1f879a323b4a4aa50fa230dc1f21);
#
#
#             circle_marker_d9c9b0391441d5852e9208fc089692f9.bindTooltip(
#                 `&lt;div&gt;
#                      4 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A5. **1431 N Hobart Blvd — East Hollywood** · 73 · ~1.1 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.097350,-118.306001)
#
# **Why we're here:** Dense-residential refill corner, no LSD. 27% gone-on-arrival.
#
# **Known findings (from the data):** 73 reports Jan–Jun · median gap 1.1 d · LSD-serviced 0% · gone-on-arrival 27% · neighborhood: EAST HOLLYWOOD NC
#
# **Immediate area (drive/walk the block):** 482 more reports at 151 other spots within 250m — this pin is only ~9% of local activity. Pin type: 6 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[4], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1234ef7875f9e6336c7dda969a686744 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1234ef7875f9e6336c7dda969a686744&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1234ef7875f9e6336c7dda969a686744 = L.map(
#                 &quot;map_1234ef7875f9e6336c7dda969a686744&quot;,
#                 {
#                     center: [34.09735006849315, -118.3060007260274],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb5c9f602141600a6dfcc5abe22d02ce = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb5c9f602141600a6dfcc5abe22d02ce.addTo(map_1234ef7875f9e6336c7dda969a686744);
#
#
#             var circle_marker_3eb3af92bd4298fdf1060af12981fa84 = L.circleMarker(
#                 [34.094556, -118.306652],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1234ef7875f9e6336c7dda969a686744);
#
#
#             circle_marker_3eb3af92bd4298fdf1060af12981fa84.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a84ac1ac1a7efeda847db86d9f0f05f6 = L.circleMarker(
#                 [34.094637, -118.307223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1234ef7875f9e6336c7dda969a686744);
#
#
#             circle_marker_a84ac1ac1a7efeda847db86d9f0f05f6.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_11b9802e4c6ff06047dc7fc9dde593ff = L.circleMarker(
#                 [34.094664, -118.305832],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1234ef7875f9e6336c7dda969a686744);
#
#
#             circle_marker_11b9802e4c6ff06047dc7fc9dde593ff.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b521af00265a4a7fda225e561d40cde4 = L.circleMarker(
#                 [34.094682, -118.307547],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.898979485566356, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1234ef7875f9e6336c7dda969a686744);
#
#
#             circle_marker_b521af00265a4a7fda225e561d40cde4.bindTooltip(
#                 `&lt;div&gt;
#                      6 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A6. **114 S New Hampshire Ave — Koreatown** · 73 · ~0.9 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.072258,-118.292527)
#
# **Why we're here:** **Pair with site #1** (400m apart): the non-encampment control that *stayed active* after #1 went quiet. Same street grid, different mechanism?
#
# **Known findings (from the data):** 73 reports Jan–Jun · median gap 0.9 d · LSD-serviced 0% · gone-on-arrival 14% · neighborhood: WILSHIRE CENTER - KOREATOWN NC
#
# **Immediate area (drive/walk the block):** 306 more reports at 114 other spots within 250m — this pin is only ~16% of local activity. Pin type: 4 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[5], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f5dc993640af885708bd13c512b52a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f5dc993640af885708bd13c512b52a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f5dc993640af885708bd13c512b52a2 = L.map(
#                 &quot;map_8f5dc993640af885708bd13c512b52a2&quot;,
#                 {
#                     center: [34.07225757534246, -118.2925268630137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f41682a086770349955561e3db1e9179 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f41682a086770349955561e3db1e9179.addTo(map_8f5dc993640af885708bd13c512b52a2);
#
#
#             var circle_marker_80adaa139ddacc15370c75f83c4b2cdf = L.circleMarker(
#                 [34.069293, -118.292382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.211102550927978, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8f5dc993640af885708bd13c512b52a2);
#
#
#             circle_marker_80adaa139ddacc15370c75f83c4b2cdf.bindTooltip(
#                 `&lt;div&gt;
#                      13 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_30e351c5e63cbf2de35b83577f3921c3 = L.circleMarker(
#                 [34.069311, -118.293232],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8f5dc993640af885708bd13c512b52a2);
#
#
#             circle_marker_30e351c5e63cbf2de35b83577f3921c3.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_32f1f0d86f5c591543ccb4c5f7c2da9a = L.circleMarker(
#                 [34.069437, -118.293822],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8f5dc993640af885708bd13c512b52a2);
#
#
#             circle_marker_32f1f0d86f5c591543ccb4c5f7c2da9a.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ccc3cb920217490fbf0d188d1eb4a897 = L.circleMarker(
#                 [34.069455, -118.293314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.16515138991168, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8f5dc993640af885708bd13c512b52a2);
#
#
#             circle_marker_ccc3cb920217490fbf0d188d1eb4a897.bindTooltip(
#                 `&lt;div&gt;
#                      21 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A7. **1342 S Elwood St — Downtown (Fashion District edge)** · 65 · ~0.5 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.025144,-118.235584)
#
# **Why we're here:** Encampment-adjacent, sub-daily re-reports, 8% gone-on-arrival.
#
# **Known findings (from the data):** 65 reports Jan–Jun · median gap 0.5 d · LSD-serviced 100% · gone-on-arrival 8% · neighborhood: DOWNTOWN LOS ANGELES
#
# **Immediate area (drive/walk the block):** 378 more reports at 79 other spots within 250m — this pin is only ~15% of local activity. Pin type: 3 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[6], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_897c99a66fdbfd66d181c6cacc686045 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_897c99a66fdbfd66d181c6cacc686045&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_897c99a66fdbfd66d181c6cacc686045 = L.map(
#                 &quot;map_897c99a66fdbfd66d181c6cacc686045&quot;,
#                 {
#                     center: [34.02514398461539, -118.23558369230769],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dc07e681cbb815b43bd33f862c6e223 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7dc07e681cbb815b43bd33f862c6e223.addTo(map_897c99a66fdbfd66d181c6cacc686045);
#
#
#             var circle_marker_9b33753977edd01c89a2289e20a3f468 = L.circleMarker(
#                 [34.022916, -118.237648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_897c99a66fdbfd66d181c6cacc686045);
#
#
#             circle_marker_9b33753977edd01c89a2289e20a3f468.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_aff25055dfe44b3d1f62ed856b2800d9 = L.circleMarker(
#                 [34.023393, -118.236766],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_897c99a66fdbfd66d181c6cacc686045);
#
#
#             circle_marker_aff25055dfe44b3d1f62ed856b2800d9.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_45ff102da8b5b82c8dd830061d59f2fe = L.circleMarker(
#                 [34.023435, -118.233034],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_897c99a66fdbfd66d181c6cacc686045);
#
#
#             circle_marker_45ff102da8b5b82c8dd830061d59f2fe.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1ea5201498e8728e58fefca57bce7003 = L.circleMarker(
#                 [34.023483, -118.23359],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.898979485566356, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_897c99a66fdbfd66d181c6cacc686045);
#
#
#             circle_marker_1ea5201498e8728e58fefca57bce7003.bindTooltip(
#                 `&lt;div&gt;
#                      6 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A8. **1201 W 39th Pl — South LA** · 63 · ~2.0 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.014369,-118.297508)
#
# **Why we're here:** Classic residential refill corner in the highest-intensity APC.
#
# **Known findings (from the data):** 63 reports Jan–Jun · median gap 2.0 d · LSD-serviced 0% · gone-on-arrival 14% · neighborhood: EMPOWERMENT CONGRESS NORTH AREA NC
#
# **Immediate area (drive/walk the block):** 332 more reports at 122 other spots within 250m — this pin is only ~7% of local activity. Pin type: 2 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[7], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4871a936d4fa13b872474b230d28866 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4871a936d4fa13b872474b230d28866&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4871a936d4fa13b872474b230d28866 = L.map(
#                 &quot;map_e4871a936d4fa13b872474b230d28866&quot;,
#                 {
#                     center: [34.014369428571435, -118.297508],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5ea5afcd7cfde72fc4a1b5801ad260b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5ea5afcd7cfde72fc4a1b5801ad260b.addTo(map_e4871a936d4fa13b872474b230d28866);
#
#
#             var circle_marker_dba91d57f4e935b903711f0e9003ab9c = L.circleMarker(
#                 [34.011279, -118.297566],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_e4871a936d4fa13b872474b230d28866);
#
#
#             circle_marker_dba91d57f4e935b903711f0e9003ab9c.bindTooltip(
#                 `&lt;div&gt;
#                      9 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_843d2f6e4a7d7752ed8a0a6f1f204d93 = L.circleMarker(
#                 [34.011405, -118.296225],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.4641016151377544, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_e4871a936d4fa13b872474b230d28866);
#
#
#             circle_marker_843d2f6e4a7d7752ed8a0a6f1f204d93.bindTooltip(
#                 `&lt;div&gt;
#                      3 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ef2164af90c4c77b2f323d12eba1eb90 = L.circleMarker(
#                 [34.01154, -118.296198],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_e4871a936d4fa13b872474b230d28866);
#
#
#             circle_marker_ef2164af90c4c77b2f323d12eba1eb90.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b8fbe437562804336887baf40fd02d2b = L.circleMarker(
#                 [34.011612, -118.29604],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_e4871a936d4fa13b872474b230d28866);
#
#
#             circle_marker_b8fbe437562804336887baf40fd02d2b.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             va

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A9. **345 Columbia Ave — Westlake** · 63 · ~1.4 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=34.058439,-118.265332)
#
# **Why we're here:** **32% gone-on-arrival** — highest on this list. Who clears it first?
#
# **Known findings (from the data):** 63 reports Jan–Jun · median gap 1.4 d · LSD-serviced 0% · gone-on-arrival 32% · neighborhood: WESTLAKE NORTH NC
#
# **Immediate area (drive/walk the block):** 317 more reports at 106 other spots within 250m — this pin is only ~17% of local activity. Pin type: single-address stack — one exact coordinate; treat the pin as the block's reporting anchor, not the exact curb.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[8], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbed2924af651ff27e0c97db92796803 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbed2924af651ff27e0c97db92796803&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbed2924af651ff27e0c97db92796803 = L.map(
#                 &quot;map_dbed2924af651ff27e0c97db92796803&quot;,
#                 {
#                     center: [34.058439, -118.2653325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa2c9fe168493e26f90cc6a948d39f30 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa2c9fe168493e26f90cc6a948d39f30.addTo(map_dbed2924af651ff27e0c97db92796803);
#
#
#             var circle_marker_e280795bfa3a5ebca376b8f93ad00d65 = L.circleMarker(
#                 [34.055388, -118.265908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dbed2924af651ff27e0c97db92796803);
#
#
#             circle_marker_e280795bfa3a5ebca376b8f93ad00d65.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_0b003e96aed6a0e0784cc665e05a16a2 = L.circleMarker(
#                 [34.055406, -118.26491],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dbed2924af651ff27e0c97db92796803);
#
#
#             circle_marker_0b003e96aed6a0e0784cc665e05a16a2.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8176638268552d8486f416950d586b68 = L.circleMarker(
#                 [34.055498, -118.265578],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dbed2924af651ff27e0c97db92796803);
#
#
#             circle_marker_8176638268552d8486f416950d586b68.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3e6abd0d4c36412964ab30d796108104 = L.circleMarker(
#                 [34.055523, -118.266129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dbed2924af651ff27e0c97db92796803);
#
#
#             circle_marker_3e6abd0d4c36412964ab30d796108104.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_08ce557112

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## A10. **Gramercy Pl & Gage Ave — South LA** · 60 · ~2.0 days
#
# [Open in Google Maps](https://www.google.com/maps/search/?api=1&query=33.981850,-118.313378)
#
# **Why we're here:** Intersection refill site; mostly regular LASAN service.
#
# **Known findings (from the data):** 60 reports Jan–Jun · median gap 2.0 d · LSD-serviced 13% · gone-on-arrival 12% · neighborhood: EMPOWERMENT CONGRESS CENTRAL AREA NC
#
# **Immediate area (drive/walk the block):** 143 more reports at 85 other spots within 250m — this pin is only ~25% of local activity. Pin type: 9 distinct coordinates — genuine spatial cluster.
#
# **Research questions:** What appears to be generating the dumping here? Why here instead of nearby? Does the data's explanation seem accurate?

# %%
stop_map(A.iloc[9], A, color="crimson")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59ed3fc19d70fecfc6149dc976efc1f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59ed3fc19d70fecfc6149dc976efc1f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59ed3fc19d70fecfc6149dc976efc1f9 = L.map(
#                 &quot;map_59ed3fc19d70fecfc6149dc976efc1f9&quot;,
#                 {
#                     center: [33.981850159864535, -118.31337789311632],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9316e0b3b81b51facc18128ecdc7056 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9316e0b3b81b51facc18128ecdc7056.addTo(map_59ed3fc19d70fecfc6149dc976efc1f9);
#
#
#             var circle_marker_daa31533e0b2f1fa78a70d9187704501 = L.circleMarker(
#                 [33.97932, -118.31224],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_59ed3fc19d70fecfc6149dc976efc1f9);
#
#
#             circle_marker_daa31533e0b2f1fa78a70d9187704501.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2a2f908aae6e127353780c15a5c64f4f = L.circleMarker(
#                 [33.97932, -118.311512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_59ed3fc19d70fecfc6149dc976efc1f9);
#
#
#             circle_marker_2a2f908aae6e127353780c15a5c64f4f.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_33708f155adaab29d79fa1985e810af5 = L.circleMarker(
#                 [33.979329, -118.31539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_59ed3fc19d70fecfc6149dc976efc1f9);
#
#
#             circle_marker_33708f155adaab29d79fa1985e810af5.bindTooltip(
#                 `&lt;div&gt;
#                      1 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6b158115abc387784f4d81160a3ee4e1 = L.circleMarker(
#                 [33.979329, -118.315125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkorange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkorange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_59ed3fc19d70fecfc6149dc976efc1f9);
#
#
#             circle_marker_6b158115abc387784f4d81160a3ee4e1.bindTooltip(
#                 `&lt;div&gt;
#                      2 reports at this spot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_mark

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ---
#
# # Comparison Sites
#
# Not "nice places" — *controls*. Each combines below-average dumping mix,
# few/no chronic sites, and healthy overall 311 use (so people demonstrably
# do report — quiet-≠-clean partially controlled). Watch for what's
# *different*: alley presence, bin access, frontage upkeep, cameras, signage,
# private security/BID crews, renter vs owner housing stock.

# %% [markdown]
# ## C1. **Studio City — Ventura Blvd (Laurel Canyon ↔ Coldwater)** · 0.59x
#
# [Open area in Google Maps](https://www.google.com/maps/search/?api=1&query=Ventura+Blvd+%26+Laurel+Canyon+Blvd,+Studio+City,+CA)
#
# **Why we're here:** citywide mix, **zero** chronic sites. Primary control; one NC boundary from Van Nuys. Covered by Route stops 8–9.
#
# **Known findings (from the data):** see the clean-comparison table in notebook 06 — below-mix dumping share, few or no chronic places, healthy overall 311 engagement.
#
# **Research questions:** What is *different* here — alleys, bin access, frontage upkeep, cameras, BID/private crews, housing stock? Would the chronic-site mechanisms we see elsewhere even have room to operate?

# %%
poly = bounds[bounds["NAME"] == "STUDIO CITY NC"]
m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(poly.to_json(), style_function=lambda f: {"color": "seagreen", "weight": 2,
               "fillColor": "seagreen", "fillOpacity": 0.2},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m)
m.fit_bounds([[poly.total_bounds[1], poly.total_bounds[0]],
              [poly.total_bounds[3], poly.total_bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e36262f02737d070318aff9cb6dcc10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e36262f02737d070318aff9cb6dcc10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e36262f02737d070318aff9cb6dcc10 = L.map(
#                 &quot;map_4e36262f02737d070318aff9cb6dcc10&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45956c744910b9364f5741a2c6eddbee = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45956c744910b9364f5741a2c6eddbee.addTo(map_4e36262f02737d070318aff9cb6dcc10);
#
#
#         function geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5ca4f51ab056017cb7f427a5e00fbfd9 = L.geoJson(null, {
#                 onEachFeature: geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_onEachFeature,
#
#                 style: geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_styler,
#             ...{
# }
#         });
#
#         function geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_add (data) {
#             geo_json_5ca4f51ab056017cb7f427a5e00fbfd9
#                 .addData(data);
#         }
#             geo_json_5ca4f51ab056017cb7f427a5e00fbfd9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.36235821992162, 34.14194052673188], [-118.36236046195847, 34.14202075130586], [-118.36236101219518, 34.14219342715661], [-118.36236121756465, 34.14226355251866], [-118.36236155635261, 34.142372202818805], [-118.36236189514148, 34.14248085311921], [-118.36236223381391, 34.14258947637406], [-118.36236257260451, 34.142698126674915], [-118.36236291139602, 34.14280677697606], [-118.3623631736177, 34.14287475921753], [-118.36236238239675, 34.14287432885181], [-118.36235323551168, 34.1428693482356], [-118.36234045632665, 34.14286237439097], [-118.36229505087186, 34.142837565871865], [-118.36226897077918, 34.142823320422465], [-118.36216526886552, 34.14276616452279], [-118.36210091894554, 34.142731327199385], [-118.36205929567916, 34.142708791755936], [-118.36205800272101, 34.14271042830984], [-118.36203297321076, 34.14274320378102], [-118.36202331495083, 34.14275432880892], [-118.36201539650804, 34.14276434965373], [-118.36197078226849, 34.142824805918536], [-118.36197053541663, 34.142825140225945], [-118.36196098504637, 34.142837897607464], [-118.36194956298677, 34.14285235638124], [-118.361935896835, 34.14286965449849], [-118.36193587742368, 34.14286967889803], [-118.36192235360848, 34.14288679628046], [-118.3619142570453, 34.142897004269805], [-118.3619031536293, 34.142910183707166], [-118.36189493912154, 34.14292119982457], [-118.3618850766527, 34.14293325133007], [-118.36187686065304, 34.1429439239655], [-118.36187357514491, 34.14294839910794], [-118.36186535616797, 34.142958384781046], [-118.36185519800614, 34.142971763328624], [-118.36185385465318, 34.142973532556965], [-118.36185132772279, 34.14297665943508], [-118.36183613986991, 34.14299586523812], [-118.36182806504127, 34.14300608938424], [-118.3618193441358, 34.14301760195535], [-118.3618045526284, 34.14303619442528], [-118.36178980209412, 34.14305473538319], [-118.36178976111444, 34.14305478689337], [-118.36149932761556, 34.14314977065449], [-118.36154433183738, 34.143234488640395], [-118.36158099501172, 34.14330548313363], [-118.36164359539116, 34.143423074351425], [-118.36176592599348, 34.14365286417875], [-118.36183323448374, 34.14376460286483], [-118.36205217999218, 34.1441280714565

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## C2. **Sherman Oaks — Ventura corridor** · 0.82x, low intensity. The gradient
#
# [Open area in Google Maps](https://www.google.com/maps/search/?api=1&query=Ventura+Blvd+%26+Van+Nuys+Blvd,+Sherman+Oaks,+CA)
#
# **Why we're here:** case: same boulevard as Studio City, 2km from Van Nuys's worst blocks.
#
# **Known findings (from the data):** see the clean-comparison table in notebook 06 — below-mix dumping share, few or no chronic places, healthy overall 311 engagement.
#
# **Research questions:** What is *different* here — alleys, bin access, frontage upkeep, cameras, BID/private crews, housing stock? Would the chronic-site mechanisms we see elsewhere even have room to operate?

# %%
poly = bounds[bounds["NAME"] == "SHERMAN OAKS NC"]
m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(poly.to_json(), style_function=lambda f: {"color": "seagreen", "weight": 2,
               "fillColor": "seagreen", "fillOpacity": 0.2},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m)
m.fit_bounds([[poly.total_bounds[1], poly.total_bounds[0]],
              [poly.total_bounds[3], poly.total_bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_557f1c3607bbea579d087654359b278c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_557f1c3607bbea579d087654359b278c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_557f1c3607bbea579d087654359b278c = L.map(
#                 &quot;map_557f1c3607bbea579d087654359b278c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af69e551e84d5ac8388658b0fd03e087 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af69e551e84d5ac8388658b0fd03e087.addTo(map_557f1c3607bbea579d087654359b278c);
#
#
#         function geo_json_3f0fb990528b9b35aeb00399b09ea924_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_3f0fb990528b9b35aeb00399b09ea924_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3f0fb990528b9b35aeb00399b09ea924 = L.geoJson(null, {
#                 onEachFeature: geo_json_3f0fb990528b9b35aeb00399b09ea924_onEachFeature,
#
#                 style: geo_json_3f0fb990528b9b35aeb00399b09ea924_styler,
#             ...{
# }
#         });
#
#         function geo_json_3f0fb990528b9b35aeb00399b09ea924_add (data) {
#             geo_json_3f0fb990528b9b35aeb00399b09ea924
#                 .addData(data);
#         }
#             geo_json_3f0fb990528b9b35aeb00399b09ea924_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.46338736723544, 34.13082648035109], [-118.46338080423597, 34.13083474918796], [-118.46337424124013, 34.13084301892604], [-118.463367676334, 34.130850944283], [-118.46336111033747, 34.13085886874215], [-118.46335454352477, 34.13086645061912], [-118.4633509433805, 34.13087079721843], [-118.46333681238093, 34.13094483622416], [-118.46332215978892, 34.13098267320478], [-118.46330088802263, 34.13102432292171], [-118.4632582171746, 34.13107703269571], [-118.4632088426546, 34.131110882694855], [-118.46315443485418, 34.13113169225866], [-118.46303576110417, 34.13118230316656], [-118.46299453028436, 34.131195183626986], [-118.46294829111707, 34.13120049409584], [-118.46290367274213, 34.13119895655698], [-118.46285737824506, 34.13119192693063], [-118.46254636352913, 34.1311209925111], [-118.46249341037488, 34.131102990345894], [-118.46245198317108, 34.13108528123723], [-118.46234262007032, 34.13102661089707], [-118.46219851615461, 34.130958126619866], [-118.46207764004589, 34.13091359202697], [-118.46198166361839, 34.13088854809443], [-118.46168891027307, 34.130828521528954], [-118.46161609445198, 34.13081057951976], [-118.46156148227259, 34.13078950362507], [-118.46141235078126, 34.13071622339231], [-118.46122845252476, 34.13062109160516], [-118.46115696732281, 34.1305402889169], [-118.46111876449645, 34.13050816676342], [-118.46108561612456, 34.13048630917728], [-118.46104755289926, 34.13047752191439], [-118.46099303328732, 34.13047532725209], [-118.4609715385672, 34.13047437606303], [-118.46088393196773, 34.130465769565376], [-118.46085970814856, 34.13046180229452], [-118.46084094347559, 34.13045872836654], [-118.46073762326236, 34.130435301763754], [-118.46063083391076, 34.130411086824665], [-118.46055808184359, 34.130398311561265], [-118.46048206760196, 34.1303951654021], [-118.46042426186067, 34.13039883399277], [-118.46036648081736, 34.130407972100976], [-118.46026253543485, 34.13043379856856], [-118.46021799837179, 34.13045009578496], [-118.46012069459279, 34.130479337116924], [-118.46001173501486, 34.13049965421598], [-118.45996221657538, 34.13050535827575], [-118.4599011062392, 34.13050901034154], [-118.45952610851197, 34.13052110265651], [-1

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## C3. **Woodland Hills–Warner Center** · 12.5% dumping share on high total 311
#
# [Open area in Google Maps](https://www.google.com/maps/search/?api=1&query=Warner+Center,+Woodland+Hills,+CA)
#
# **Why we're here:** engagement (13.4K cases — heavy reporters, few dump reports). Best commercial-corridor control. West of Reseda; pairs with Route stop 1 day.
#
# **Known findings (from the data):** see the clean-comparison table in notebook 06 — below-mix dumping share, few or no chronic places, healthy overall 311 engagement.
#
# **Research questions:** What is *different* here — alleys, bin access, frontage upkeep, cameras, BID/private crews, housing stock? Would the chronic-site mechanisms we see elsewhere even have room to operate?

# %%
poly = bounds[bounds["NAME"] == "WOODLAND HILLS-WARNER CENTER NC"]
m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(poly.to_json(), style_function=lambda f: {"color": "seagreen", "weight": 2,
               "fillColor": "seagreen", "fillOpacity": 0.2},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m)
m.fit_bounds([[poly.total_bounds[1], poly.total_bounds[0]],
              [poly.total_bounds[3], poly.total_bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f13956894aa64b0644751c5643f80ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f13956894aa64b0644751c5643f80ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f13956894aa64b0644751c5643f80ef = L.map(
#                 &quot;map_9f13956894aa64b0644751c5643f80ef&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22bfef87a34644bb82aae8f6d91dba30 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22bfef87a34644bb82aae8f6d91dba30.addTo(map_9f13956894aa64b0644751c5643f80ef);
#
#
#         function geo_json_5bc20baf98ced13c5451601ffa55d593_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5bc20baf98ced13c5451601ffa55d593_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5bc20baf98ced13c5451601ffa55d593 = L.geoJson(null, {
#                 onEachFeature: geo_json_5bc20baf98ced13c5451601ffa55d593_onEachFeature,
#
#                 style: geo_json_5bc20baf98ced13c5451601ffa55d593_styler,
#             ...{
# }
#         });
#
#         function geo_json_5bc20baf98ced13c5451601ffa55d593_add (data) {
#             geo_json_5bc20baf98ced13c5451601ffa55d593
#                 .addData(data);
#         }
#             geo_json_5bc20baf98ced13c5451601ffa55d593_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.66816006582133, 34.17695952813129], [-118.66815865045372, 34.1767570639272], [-118.6680576273614, 34.17675671955681], [-118.6678668680822, 34.17675578792367], [-118.66751210894537, 34.17675406816492], [-118.66742532861196, 34.17675360949404], [-118.66740978444015, 34.17675362044724], [-118.667086436339, 34.17675384293383], [-118.66695583807949, 34.17675351472058], [-118.66671615574246, 34.17675347944273], [-118.66636156432956, 34.17675374059865], [-118.66605820938386, 34.17675387451694], [-118.66578960100928, 34.17675391286095], [-118.6655335124385, 34.17675392408525], [-118.6655217842411, 34.17675391920569], [-118.66525730017948, 34.17675397514294], [-118.66501182702365, 34.17675400981223], [-118.66498949675018, 34.176754020805305], [-118.66473822093894, 34.176754003882536], [-118.66462085067906, 34.17675362838841], [-118.66457457689127, 34.176753756458425], [-118.66425055927884, 34.17675394348766], [-118.66385630110227, 34.1767536317103], [-118.6637736488844, 34.17675366524934], [-118.66354470120385, 34.17675377483022], [-118.66344468426303, 34.176754045860775], [-118.66311672721886, 34.176753998127325], [-118.66295454830164, 34.176753977585534], [-118.66284957853894, 34.17675357476905], [-118.66254210273, 34.17675370622565], [-118.66203542506457, 34.1767536977978], [-118.66153950110379, 34.17675364194843], [-118.66147916075509, 34.17675380520732], [-118.66104356304281, 34.17675358414255], [-118.66102373959727, 34.17675359512615], [-118.66047301418249, 34.176753728037596], [-118.6604583901603, 34.176753775445086], [-118.66037572094076, 34.17675398886786], [-118.66023051715355, 34.176753704293326], [-118.66007981465563, 34.1767533954631], [-118.65994178156154, 34.1767533229372], [-118.65990231006938, 34.17675330301311], [-118.65988259276655, 34.17675329339639], [-118.659648349839, 34.17675317566572], [-118.65936402834345, 34.17675324397104], [-118.65907886393096, 34.176753301776735], [-118.6590236196317, 34.17675332244339], [-118.65877387650595, 34.176753424517024], [-118.6586206895332, 34.17675319591959], [-118.65860316447088, 34.1767531849743], [-118.65860162323462, 34.176721972691766], [-118.65860179064903, 34.176711286609816], [-118.6586

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## C4. **Granada Hills North** · 11.6% share. "Ordinary but clean" single-family
#
# [Open area in Google Maps](https://www.google.com/maps/search/?api=1&query=Granada+Hills,+Los+Angeles,+CA)
#
# **Why we're here:** Valley control — demographically closer to Reseda than Porter Ranch is.
#
# **Known findings (from the data):** see the clean-comparison table in notebook 06 — below-mix dumping share, few or no chronic places, healthy overall 311 engagement.
#
# **Research questions:** What is *different* here — alleys, bin access, frontage upkeep, cameras, BID/private crews, housing stock? Would the chronic-site mechanisms we see elsewhere even have room to operate?

# %%
poly = bounds[bounds["NAME"] == "GRANADA HILLS NORTH NC"]
m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(poly.to_json(), style_function=lambda f: {"color": "seagreen", "weight": 2,
               "fillColor": "seagreen", "fillOpacity": 0.2},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m)
m.fit_bounds([[poly.total_bounds[1], poly.total_bounds[0]],
              [poly.total_bounds[3], poly.total_bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98e7654537d872cbf4520fc249ea51f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98e7654537d872cbf4520fc249ea51f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98e7654537d872cbf4520fc249ea51f3 = L.map(
#                 &quot;map_98e7654537d872cbf4520fc249ea51f3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_702b6ded5476fc95cfd04e4b466df8be = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_702b6ded5476fc95cfd04e4b466df8be.addTo(map_98e7654537d872cbf4520fc249ea51f3);
#
#
#         function geo_json_7104e6592c94858fb435fb0ab14aa18c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_7104e6592c94858fb435fb0ab14aa18c_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7104e6592c94858fb435fb0ab14aa18c = L.geoJson(null, {
#                 onEachFeature: geo_json_7104e6592c94858fb435fb0ab14aa18c_onEachFeature,
#
#                 style: geo_json_7104e6592c94858fb435fb0ab14aa18c_styler,
#             ...{
# }
#         });
#
#         function geo_json_7104e6592c94858fb435fb0ab14aa18c_add (data) {
#             geo_json_7104e6592c94858fb435fb0ab14aa18c
#                 .addData(data);
#         }
#             geo_json_7104e6592c94858fb435fb0ab14aa18c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.53657263158097, 34.2932936636314], [-118.53630557473903, 34.2930343196201], [-118.53612766164456, 34.29286154324231], [-118.5361269752028, 34.2928608764348], [-118.53595558183156, 34.29269443223004], [-118.53572123611158, 34.29246685408451], [-118.53551305688511, 34.29229717135624], [-118.53539260267577, 34.29219898950352], [-118.53477609492815, 34.29169646364211], [-118.53462312182887, 34.29157179485374], [-118.53455190127099, 34.291496634788224], [-118.53435892705883, 34.29129298587777], [-118.5343557566924, 34.29128964071846], [-118.53406395795125, 34.29098169784015], [-118.53333485929336, 34.29021224830201], [-118.53332604940847, 34.29020294982271], [-118.5332940053532, 34.29016913252948], [-118.5329516814821, 34.289702745193296], [-118.5329469402461, 34.28969628486848], [-118.53280921475654, 34.289508643378134], [-118.53217204754014, 34.288640535916144], [-118.53201868114499, 34.288431577678466], [-118.53159457757256, 34.28785374279281], [-118.53113837909876, 34.28745585897186], [-118.53041487356037, 34.28682482190809], [-118.53008199409821, 34.286534483490136], [-118.52927443121062, 34.28583012451196], [-118.52899963535923, 34.28559044478636], [-118.52832602299259, 34.28500291392545], [-118.52815940045275, 34.28424182383563], [-118.52804320725942, 34.28371107320333], [-118.5278677878329, 34.282909774411856], [-118.5278510751188, 34.2828334244076], [-118.52779250619288, 34.28256581338789], [-118.52773370441432, 34.282051663033236], [-118.52763023110381, 34.28114690033895], [-118.52757906610964, 34.280699513715334], [-118.52743784494798, 34.280316444135565], [-118.52709977871434, 34.279399410238575], [-118.52697109472005, 34.27905033861281], [-118.52695915466799, 34.278784139821504], [-118.52692773924983, 34.278181314965444], [-118.52678648052377, 34.27821157410819], [-118.52661779272154, 34.27823326060773], [-118.52633652089038, 34.27824925351762], [-118.52599238263585, 34.27826998421456], [-118.52565310237352, 34.27827351845953], [-118.52465005354074, 34.27826790747985], [-118.52443621494567, 34.27826575774778], [-118.52440415718407, 34.27826543499701], [-118.52249955897838, 34.27824626781398], [-118.52228636890231, 34.278244120502876],

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ## C5. **Porter Ranch** · 5.2% share
#
# [Open area in Google Maps](https://www.google.com/maps/search/?api=1&query=Porter+Ranch,+Los+Angeles,+CA)
#
# **Why we're here:** citywide minimum among engaged NCs. The near-zero anchor; note how much built form (HOA, no alleys, no aging commercial strip) explains before any city service does.
#
# **Known findings (from the data):** see the clean-comparison table in notebook 06 — below-mix dumping share, few or no chronic places, healthy overall 311 engagement.
#
# **Research questions:** What is *different* here — alleys, bin access, frontage upkeep, cameras, BID/private crews, housing stock? Would the chronic-site mechanisms we see elsewhere even have room to operate?

# %%
poly = bounds[bounds["NAME"] == "PORTER RANCH NC"]
m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(poly.to_json(), style_function=lambda f: {"color": "seagreen", "weight": 2,
               "fillColor": "seagreen", "fillOpacity": 0.2},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m)
m.fit_bounds([[poly.total_bounds[1], poly.total_bounds[0]],
              [poly.total_bounds[3], poly.total_bounds[2]]])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c23b6fac9c420e85fb7a429e5135a10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c23b6fac9c420e85fb7a429e5135a10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c23b6fac9c420e85fb7a429e5135a10 = L.map(
#                 &quot;map_5c23b6fac9c420e85fb7a429e5135a10&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_977199463e62df33292770f46bf851eb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_977199463e62df33292770f46bf851eb.addTo(map_5c23b6fac9c420e85fb7a429e5135a10);
#
#
#         function geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a19333e6307f3bc58f09f76b3a1c1bdc = L.geoJson(null, {
#                 onEachFeature: geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_onEachFeature,
#
#                 style: geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_styler,
#             ...{
# }
#         });
#
#         function geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_add (data) {
#             geo_json_a19333e6307f3bc58f09f76b3a1c1bdc
#                 .addData(data);
#         }
#             geo_json_a19333e6307f3bc58f09f76b3a1c1bdc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.52737689853699, 34.27813790212976], [-118.52712933690992, 34.27817211898936], [-118.52703014931423, 34.2781832637701], [-118.52702963705758, 34.27818589940548], [-118.5269186681476, 34.27875703713171], [-118.52692021516927, 34.27875659765941], [-118.52692080293598, 34.27876832597316], [-118.5269251233944, 34.278854509964816], [-118.5269357888787, 34.27906731323657], [-118.52754232665154, 34.280712457651475], [-118.5277558278856, 34.28257807555219], [-118.52778028211118, 34.282689780978195], [-118.52781298367063, 34.28283916107314], [-118.52785107294663, 34.282833424417085], [-118.52785775999723, 34.28286396657419], [-118.52786562140902, 34.28289987410046], [-118.52786564379787, 34.28289997948332], [-118.52794697163141, 34.28327145081604], [-118.52810386159915, 34.2839880492463], [-118.52810387835838, 34.28398812309967], [-118.52811442988248, 34.28403631862229], [-118.528220782297, 34.28452207736022], [-118.52826062153979, 34.28470409900138], [-118.52829450614497, 34.2848589182211], [-118.52829881007325, 34.28487857921568], [-118.52832602299259, 34.28500291392545], [-118.5286134011431, 34.28525356881197], [-118.52869007827299, 34.285320446776616], [-118.52899963643964, 34.28559044388008], [-118.52904637545804, 34.28563123824599], [-118.52923353093072, 34.28579444350886], [-118.52942062087676, 34.28595764787004], [-118.52961899595337, 34.28613066817034], [-118.52980588834232, 34.286293653730766], [-118.53008199842552, 34.28653448076654], [-118.53009000319456, 34.28654146063004], [-118.5300992312514, 34.28654950977691], [-118.53028503767867, 34.28671154642769], [-118.53038759659022, 34.28680102705969], [-118.53041487139959, 34.28682482372067], [-118.53043789855612, 34.286844908397924], [-118.53159457757256, 34.28785374279281], [-118.53181824458969, 34.28815848647791], [-118.53190317064235, 34.288274197021515], [-118.53236483724827, 34.288903204062684], [-118.53244846968094, 34.28901714928549], [-118.5329469402461, 34.28969628486848], [-118.53327000856797, 34.29013643917686], [-118.5332940053532, 34.29016913252948], [-118.53333485929336, 34.29021224830201], [-118.53333507145138, 34.29021247275336], [-118.53406395795125, 34.29098169784015], [-118.

# %% [markdown]
# **Field Taxonomy** (keep what applies; add detail after any item):
#
# - **Land use:** apartment/multifamily · single-family residential · retail/commercial · industrial · mixed-use · vacant lot
# - **Disposal infrastructure:** shared dumpsters · shared curb bins · private bins · overflowing bins · no nearby bins
# - **Physical geometry:** alley · parking entrance · median/island · wall/fence · retaining wall · wide sidewalk · recessed area · loading dock · bus stop
# - **Visibility / surveillance:** hidden from traffic · hidden from nearby buildings · high visibility · poor lighting (if observed) · security cameras visible
# - **Ownership / responsibility:** clearly public · clearly private · ambiguous ownership
# - **Existing disorder:** graffiti · litter · weeds · neglected landscaping · broken pavement · other maintenance issues:
# - **Evidence observed:** active dumping present · old dumping remnants · evidence of repeated cleanup · bulky furniture · construction debris · household trash · unknown
#
# **Initial interpretation** (observational — not conclusions):
#
# - What seems to make this place attractive?
#
# - What surprised me?
#
# - What would I change first?
#
# **Close-out:** Data's explanation accurate? (yes/partly/no): · Worth interviewing (business/resident/city worker/BID/security/other):
#
# **Observations:**
#
# *(type here during/after the visit)*

# %% [markdown]
# ---
#
# After the field day: copy filled sections into dated files in `field-notes/`,
# promote durable answers to `roadmap.md` (this domain's research tracker) and
# `docs/observatory_findings.md`, and bring surprises to the next analysis
# notebook.
