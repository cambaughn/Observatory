# %% [markdown]
# # 06 — Neighborhood Calibration: the San Fernando Valley
#
# **Question this notebook answers:** *Does lived experience of the Valley match what the data suggests?*
#
# This is a calibration exercise, not discovery: before the first field visits, we pin the data's view of neighborhoods we know personally, so that when we stand on a corner we can tell whether the data lied, the intuition lied, or both. The output is a comparison table, a set of calibration prompts, and the **field program** (chronic hotspots + Valley revisit sites + clean comparisons).
#
# ## Geography mapping
#
# The dataset's finest reliable geography is the Neighborhood Council. Colloquial neighborhoods ≠ NC boundaries, so we map explicitly — and note the seams:
#
# | Neighborhood | NC(s) used | Seam notes |
# |---|---|---|
# | Van Nuys | VAN NUYS NC | core Van Nuys; Lake Balboa & Valley Glen are separate NCs, excluded |
# | Panorama City | PANORAMA CITY NC | — |
# | Sherman Oaks | SHERMAN OAKS NC | — |
# | Studio City | STUDIO CITY NC | — |
# | Encino | ENCINO NC | — |
# | North Hollywood | NOHO NC + NOHO WEST NC + NORTH HOLLYWOOD NORTH EAST NC | three NCs cover colloquial NoHo |
# | Reseda | RESEDA NC | included — it kept forcing itself into every prior notebook |
#
# ## Filters & method
#
# Standard operational filter (standards §1), Jan–Jun 2026. Places = 20m clusters computed **citywide** (same pipeline as notebook 05 — a place near an NC boundary is still one place), then attributed to neighborhoods by their reports' NC field. Duration metrics: cases created before June 1, LASAN track only (holding the two-track split of F15 constant — LSD share is reported separately).
#
# ## On normalization
#
# Raw report counts mislead: these NCs differ several-fold in size and population. We compare **structure and rate, not volume**: 2020 Census population is joined per NC (block-level aggregation — `shared/scripts/build_nc_population_2020.py`); road-mile normalization remains future work. Metrics:
# - **dumping per 1,000 residents** (2020 Census);
# - **dumping share of the neighborhood's own 311 demand** (self-normalizing: the neighborhood is its own denominator), expressed as a ratio to the citywide 28.8%;
# - **recurring vs one-off share** of dumping reports;
# - **hotspot intensity** (reports per recurring place, and count of chronic 25+ places);
# - operational quality (median close, gone-on-arrival rate, LSD share).
#
# One warning learned while building this: the *share* metric can be gamed by the denominator — Downtown LA shows a low dumping share only because its 311 demand is flooded with encampment reports. Share must always be read next to intensity.

# %%
from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN

raw = pd.read_csv(Path("../../shared/datasets/raw/myla311_cases_2026.csv"), low_memory=False)

INTAKE_ARTIFACTS = {"Information-Only", "Feedback", "Program Research"}
DEAD_STATUSES = {"Cancelled", "Potential Duplicate", "Duplicate Confirm"}
DUP_CODES = ("DUP-", "B-Duplicated", "CDR-")

def standard_operational_filter(df):
    """Standard filter per docs/analysis_standards.md section 1."""
    out = df[~df["RequestType"].isin(INTAKE_ARTIFACTS)]
    out = out[~out["Status"].isin(DEAD_STATUSES)]
    out = out[~out["ResolutionCode"].fillna("").str.startswith(DUP_CODES)]
    return out

op = standard_operational_filter(raw).copy()
op["created"] = pd.to_datetime(op["CreatedDate"], format="mixed")
op = op[op["created"] < "2026-07-01"]

NEIGH = {
    "Van Nuys": ["VAN NUYS NC"],
    "Panorama City": ["PANORAMA CITY NC"],
    "Sherman Oaks": ["SHERMAN OAKS NC"],
    "Studio City": ["STUDIO CITY NC"],
    "Encino": ["ENCINO NC"],
    "North Hollywood": ["NOHO NC", "NOHO WEST NC", "NORTH HOLLYWOOD NORTH EAST NC"],
    "Reseda": ["RESEDA NC"],
}
NC_TO_NEIGH = {nc: n for n, ncs in NEIGH.items() for nc in ncs}
op["neigh"] = op["NCName"].map(NC_TO_NEIGH)

# citywide 20m places (same pipeline as notebook 05)
il = op[op["RequestType"] == "Illegal Dumping Item Pickup"].dropna(subset=["Latitude", "Longitude"])
il = il[il["Latitude"].between(33.60, 34.40) & il["Longitude"].between(-118.75, -118.10)]
g = gpd.GeoDataFrame(
    il, geometry=gpd.points_from_xy(il["Longitude"], il["Latitude"]), crs="EPSG:4326"
).to_crs("EPSG:32611")
g["place"] = DBSCAN(eps=20, min_samples=1).fit_predict(np.c_[g.geometry.x, g.geometry.y])
place_size = g["place"].map(g["place"].value_counts())
g["recurring"] = place_size >= 2
g["neigh"] = g["NCName"].map(NC_TO_NEIGH)

CITYWIDE_SHARE = len(il) / len(op)
print(f"citywide baselines: dumping share {CITYWIDE_SHARE:.1%} | recurring share {g['recurring'].mean():.1%}")
# Out:
# citywide baselines: dumping share 28.8% | recurring share 81.1%

# %%
# 2020 Census population per NC: block POP20 summed into certified NC
# polygons by block internal point (shared/scripts/build_nc_population_2020.py;
# validated against the official LA County 2020 total)
nc_pop_2020 = pd.read_csv("../../shared/datasets/processed/nc_population_2020.csv", index_col="NAME")["pop2020"]
NC_POP = {name: int(nc_pop_2020[ncs].sum()) for name, ncs in NEIGH.items()}

def neighborhood_profile(name):
    o = op[op["neigh"] == name]
    d = g[g["neigh"] == name]
    lasan_closed = d[(d["Status"] == "Closed") & (d["created"] < "2026-06-01")
                     & d["Owner"].isin(["LASAN", "Sanitation"])]
    days = (pd.to_datetime(lasan_closed["ClosedDate"], format="mixed")
            - lasan_closed["created"]).dt.total_seconds() / 86400
    places = d.groupby("place").size()
    share = len(d) / len(o)
    return {
        "population (2020 census)": NC_POP[name],
        "311 demand": len(o),
        "dumping reports": len(d),
        "dumping per 1k residents (6mo)": round(len(d) / NC_POP[name] * 1000, 1),
        "dumping share %": round(share * 100, 1),
        "share vs citywide": round(share / CITYWIDE_SHARE, 2),
        "% at recurring places": round(d["recurring"].mean() * 100, 1),
        "reports per recurring place": round(places[places >= 2].mean(), 1),
        "places 10+": int((places >= 10).sum()),
        "chronic places 25+": int((places >= 25).sum()),
        "median days to close (LASAN)": round(days.median(), 1),
        "% gone on arrival": round((d["ResolutionCode"] == "QC-Item Not Out").mean() * 100, 1),
        "% LSD-serviced": round(d["Owner"].isin(["LSD", "LASAN - LSD"]).mean() * 100, 1),
    }

table = pd.DataFrame({n: neighborhood_profile(n) for n in NEIGH})
table
# Out:
#                                 Van Nuys  Panorama City  Sherman Oaks  \
# population (2020 census)         85823.0        67724.0      68635.00
# 311 demand                       18275.0         8798.0      13422.00
# dumping reports                   8406.0         3289.0       3164.00
# dumping per 1k residents (6mo)      97.9           48.6         46.10
# dumping share %                     46.0           37.4         23.60
# share vs citywide                    1.6            1.3          0.82
# % at recurring places               89.4           82.2         80.60
# reports per recurring place          6.1            4.8          4.20
# places 10+                         209.0           55.0         38.00
# chronic places 25+                  31.0            4.0          4.00
# median days to close (LASAN)         2.9            3.7          2.40
# % gone on arrival                   28.3           35.6         32.30
# % LSD-serviced                      13.9            9.0         10.00
#
#                                 Studio City    Encino  North Hollywood  \
# population (2020 census)           37364.00  46935.00        122428.00
# 311 demand                          8070.00   8885.00         27344.00
# dumping reports                     1373.00   1989.00         10952.00
# dumping per 1k residents (6mo)        36.70     42.40            89.50
# dumping share %                       17.00     22.40            40.10
# share vs citywide                      0.59      0.78             1.39
# % at recurring places                 74.80     81.50            83.80
# reports per recurring place            3.90      5.70             4.60
# places 10+                            21.00     44.00           181.00
# chronic places 25+                     0.00      7.00            16.00
# median days to close (LASAN)           2.70      1.80             2.70
# % gone on arrival                     35.70     33.30            26.40
# % LSD-serviced                        12.20     12.50            20.30
#
#                                   Reseda
# population (2020 census)        70620.00
# 311 demand                      14004.00
# dumping reports                  4511.00
# dumping per 1k residents (6mo)     63.90
# dumping share %                    32.20
# share vs citywide                   1.12
# % at recurring places              82.20
# reports per recurring place         5.10
# places 10+                         81.00
# chronic places 25+                 16.00
# median days to close (LASAN)        2.70
# % gone on arrival                  27.20
# % LSD-serviced                     15.20

# %%
fig, axes = plt.subplots(1, 3, figsize=(13, 3.8))

ratio = table.loc["share vs citywide"].astype(float).sort_values()
colors = ["tab:red" if v > 1 else "tab:green" for v in ratio]
ratio.plot(kind="barh", ax=axes[0], color=colors)
axes[0].axvline(1, color="k", lw=0.8)
axes[0].set_title("Dumping share vs citywide\n(1.0 = city average mix)")

intensity = table.loc["reports per recurring place"].astype(float).sort_values()
intensity.plot(kind="barh", ax=axes[1], color="tab:red")
axes[1].set_title("Hotspot intensity\n(reports per recurring place)")

chronic = table.loc["chronic places 25+"].astype(float).sort_values()
chronic.plot(kind="barh", ax=axes[2], color="tab:red")
axes[2].set_title("Chronic places (25+ reports)")
plt.tight_layout()

# %% [markdown]
# ## Reading the comparison
#
# **Van Nuys is the Valley's dumping capital — and it's not close.** Dumping is **46% of everything Van Nuys reports to 311** (1.6x the citywide mix), with the Valley's highest intensity (6.1 reports per recurring place) and 31 chronic sites. Whatever residents feel about Van Nuys and trash: the data says it's not imagination.
#
# **North Hollywood is a volume giant with an encampment component.** Largest absolute counts here (10.9K dumping reports across its three NCs, 40% of local demand), 16 chronic sites, and the Valley's highest LSD share (20% — encampment-adjacent servicing concentrated around the NoHo core and Lankershim).
#
# **Panorama City punches above its size but *fails differently*.** 37% dumping share, only 4 chronic sites — but the Valley's **slowest closures (3.7d median vs 1.8–2.9 elsewhere) and a 36% gone-on-arrival rate**. Reports there more often end with nothing collected. Whether that's crew allocation, reporting behavior, or scavenging economics is a field/interview question.
#
# **Reseda is a corridor phenomenon.** Overall structure looks moderate (1.12x, 16 chronic sites) — but its top three places are **all on Sherman Way within a half-mile** (17900: 78 reports, 17808: 53, 17940: 45). The NC-level view *understates* Reseda; the corridor view is the true unit.
#
# **Sherman Oaks and Encino run below the citywide mix (0.82x / 0.78x) — but Encino hides pockets.** Encino has **7 chronic 25+ sites** (more than Sherman Oaks's 4 and Studio City's 0) clustered on specific residential-adjacent streets (Yarmouth, Newcastle, White Oak — all just off the Ventura corridor), *and* the Valley's fastest closures (1.8d). Low background, sharp spikes.
#
# **Studio City is the clean control.** Lowest share (17%, 0.59x), lowest recurring share (75%), lowest intensity (3.9), **zero chronic 25+ places**. Its top place (Arch Dr, 22 reports) wouldn't crack Van Nuys's top fifteen.
#
# **Per-capita view (new columns):** normalizing by 2020 Census population (block-level POP20 aggregated into NC boundaries — see `shared/scripts/build_nc_population_2020.py`) reorders the middle of the field. Van Nuys still towers (**98 dumping reports per 1,000 residents in six months** — 2.7x Studio City's 37). But **Panorama City (49/1k) drops to par with Sherman Oaks (46/1k)**: its high dumping *share* partly reflects that Panorama residents report little else to 311, not extreme per-person dumping volume. This is the reporting-propensity bias made visible — the share metric and the per-capita metric disagree *because they are biased differently* (share by local reporting mix, per-capita by reporting propensity). North Hollywood is second (90/1k) and Reseda third (64/1k), reinforcing both the NoHo-volume and corridor findings. Caveats: block internal points near NC borders can land on the wrong side (small); population ≠ exposure (daytime workers, commercial frontage don't reside anywhere); reports ≠ items (standards §6.1, §6.4).
#
# Direct structural comparison — recurring vs one-off: every neighborhood sits within a few points of the citywide 81% recurring share (Studio City lowest at 75%, Van Nuys highest at 89%). **Recurrence is not a "bad neighborhood" trait; it is the universal structure of dumping.** What varies between neighborhoods is *how many* chronic places exist and *how intense* they get — not whether dumping recurs.

# %% [markdown]
# ## Does the data match my intuition?
#
# The data's claims, phrased as testable expectations — mark each true/false against lived experience (and file the reactions as the first entry in `field-notes/`):
#
# 1. Van Nuys should *feel* like the Valley's dumping center — especially the blocks around Delano St / Erwin St west of Van Nuys Blvd, and Sherman Way. (46% share, top intensity)
# 2. NoHo's problem should feel concentrated around Lankershim and the eastern (91605) blocks, with visible encampment entanglement. (20% LSD share)
# 3. Panorama City piles should seem to "disappear on their own" more often than elsewhere. (36% gone-on-arrival)
# 4. Reseda should feel fine as a neighborhood but Sherman Way between ~17800–17950 should be visibly, chronically bad. (corridor concentration)
# 5. Sherman Oaks and Studio City should feel meaningfully cleaner than the Van Nuys border zones — with the transition noticeable within a few blocks around the Magnolia/Burbank Blvd line. (0.82x / 0.59x vs 1.60x)
# 6. Encino should mostly feel clean but with a few specific streets that residents privately know as problem spots. (7 chronic pockets on low background)
#
# Where intuition disagrees with any of these, that disagreement is *the finding* — either a reporting-bias artifact worth chasing (quiet ≠ clean) or a data artifact worth debugging.
#
# ## Which neighborhoods deserve field visits?
#
# **Van Nuys** (the phenomenon at full strength, in familiar territory), **Reseda's Sherman Way corridor** (corridor dynamics + 3 chronic sites in walking distance), **Panorama City** (the gone-on-arrival anomaly), and **NoHo's Lankershim spine** (encampment-adjacent archetype). Encino's pockets are a bonus half-day (chronic sites inside a clean background — the sharpest possible contrast over a short drive).
#
# ## Which neighborhoods should serve as "clean" comparison cases?
#
# **Studio City** first (clean by every structural measure, adjacent to Van Nuys for same-day contrast), **Sherman Oaks' Ventura corridor** second. Citywide clean candidates are computed in the field program below.
#
# ## What surprised us?
#
# - **Studio City's zero.** Not merely below average — *no* chronic 25+ site at all, uniquely among the seven.
# - **Encino's seven chronic pockets** despite a below-citywide share: "clean neighborhood" and "chronic dumping sites" coexist comfortably.
# - **Panorama City's failure mode is different in kind** — slowest closes and highest gone-on-arrival, despite moderate chronic-site count. Neighborhoods don't just differ in *how much* dumping; they differ in *how the service system performs*.
# - Recurring share barely varies (75–89%) across neighborhoods spanning 0.59x–1.60x demand mix — recurrence is structural, everywhere.
#
# ## What should we investigate in person?
#
# 1. The **Van Nuys ↔ Studio City gradient**: drive Van Nuys Blvd → Ventura Blvd; where exactly does the street character flip, and does it match the NC boundary or a land-use line?
# 2. **Sherman Way, Reseda, 17800–17950 blocks**: is this one continuous condition (storefront alleys? vacant frontage?) or three distinct spots?
# 3. **Panorama City gone-on-arrival**: visit 2–3 sites shortly after new reports appear; is material being scavenged, moved, or was it never there?
# 4. **Encino's pockets** (Yarmouth/Newcastle/White Oak): what physical feature makes these specific blocks the exception inside a clean area?
# 5. At every stop: land use, alley vs curb frontage, lighting, cameras, signage, bin access, encampment proximity — the checklist from notebook 05.
#
# ---
#
# ## Postscript: what happened at 4th St & New Hampshire Ave?
#
# The citywide #1 site went silent April 17 (F20). Cross-referencing the `Homeless Encampment` category around the same corner explains it:

# %%
site = g[g["Address"].fillna("").str.upper().str.contains("4TH ST AND NEW HAMPSHIRE")]
cx, cy = site.geometry.x.mean(), site.geometry.y.mean()

he = op[op["RequestType"] == "Homeless Encampment"].dropna(subset=["Latitude", "Longitude"])
he = he[he["Latitude"].between(33.60, 34.40) & he["Longitude"].between(-118.75, -118.10)]
gh = gpd.GeoDataFrame(he, geometry=gpd.points_from_xy(he["Longitude"], he["Latitude"]),
                      crs="EPSG:4326").to_crs("EPSG:32611")

def monthly_near(frame, radius, exclude_inner=0):
    dist = np.hypot(frame.geometry.x - cx, frame.geometry.y - cy)
    sub = frame[(dist > exclude_inner) & (dist <= radius)]
    return sub["created"].dt.to_period("M").value_counts().sort_index()

summary = pd.DataFrame({
    "dumping AT site (30m)": monthly_near(g, 30),
    "dumping nearby (30-300m)": monthly_near(g, 300, 30),
    "encampment reports (150m)": monthly_near(gh, 150),
}).fillna(0).astype(int)
summary
# Out:
#          dumping AT site (30m)  dumping nearby (30-300m)  \
# created
# 2026-01                     27                        90
# 2026-02                     34                        47
# 2026-03                     35                        80
# 2026-04                     19                        88
# 2026-05                      0                        81
# 2026-06                      0                        77
#
#          encampment reports (150m)
# created
# 2026-01                        117
# 2026-02                         84
# 2026-03                        107
# 2026-04                         72
# 2026-05                          4
# 2026-06                          4

# %% [markdown]
# **Encampment reports within 150m collapse from ~100/month to 4/month in May–June — simultaneously with the dumping silence — while dumping in the surrounding blocks continues unchanged.** The encampment on the vacant southeast corner (documented by [LAist](https://laist.com/news/mind-the-mess-koreatown-leads-la-in-illegal-dumping-reports): this corner was already the citywide #1 with 206 reports in Apr–Dec 2025) was almost certainly resolved in late April 2026. The surrounding steadiness rules out a neighborhood-wide reporting collapse, and shows the demand did *not* simply migrate next door.
#
# What the data cannot tell us: *which* intervention (a CARE+/Inside Safe operation? lot fencing? the media attention itself — LAist/The LA Local coverage ran early 2026? — note the city also moved to acquire the vacant lot three blocks east at [4th & Kingsley for a pocket park on April 2, 2026](https://laist.com/news/la-to-acquire-vacant-lot-koreatown-new-pocket-park-plan), so CD10 was actively working this corridor). And whether the *street* is actually clean now, or just unreported. Both are now specific questions for the field visit and the CD10 / LSD interviews — this site is the program's best natural experiment on "what makes a chronic site stop."
#
# ---
#
# # Field Program

# %% [markdown]
# ## A. Citywide chronic hotspots — top 10 to visit regardless of distance

# %%
g_sorted = g.sort_values(["place", "created"])
med_gap = g_sorted.groupby("place")["created"].apply(
    lambda s: s.diff().dt.total_seconds().median() / 86400 if len(s) > 1 else np.nan)

def mode_or_blank(s):
    s = s.dropna()
    return s.mode().iloc[0] if len(s) else ""

place_stats = g.groupby("place").agg(
    reports=("place", "size"),
    lat=("Latitude", "mean"),
    lon=("Longitude", "mean"),
    address=("Address", mode_or_blank),
    neighborhood=("NCName", mode_or_blank),
    council_district=("CD", mode_or_blank),
    months_active=("created", lambda s: s.dt.month.nunique()),
    lsd_share=("Owner", lambda s: s.isin(["LSD", "LASAN - LSD"]).mean()),
    gone_on_arrival=("ResolutionCode", lambda s: (s == "QC-Item Not Out").mean()),
)
place_stats["median_gap_days"] = med_gap
place_stats["last_report"] = g.groupby("place")["created"].max()

def why(r):
    notes = []
    if (pd.Timestamp("2026-06-30") - r["last_report"]).days > 45:
        notes.append(f"WENT QUIET {r['last_report']:%b %d} after heavy activity - intervention?")
    if r["lsd_share"] >= 0.5:
        notes.append("encampment-adjacent (LSD)")
    if r["gone_on_arrival"] >= 0.3:
        notes.append(f"{r['gone_on_arrival']:.0%} gone-on-arrival")
    if r["median_gap_days"] is not None and r["median_gap_days"] <= 1:
        notes.append("sub-daily report gaps")
    elif r["median_gap_days"] is not None and r["median_gap_days"] <= 2.5:
        notes.append("refills every 1-2 days")
    return "; ".join(notes) if notes else "high-volume chronic site"

citywide10 = place_stats[place_stats["months_active"] >= 4].nlargest(10, "reports").copy()
citywide10["why_interesting"] = citywide10.apply(why, axis=1)
A = citywide10.reset_index(drop=True).round({"median_gap_days": 1, "lsd_share": 2, "gone_on_arrival": 2})
A.index += 1
A[["address", "neighborhood", "council_district", "reports", "median_gap_days", "why_interesting"]]
# Out:
#                                             address  \
# 1                      4TH ST and NEW HAMPSHIRE AVE
# 2           350 N AVENUE 21, LOS ANGELES, CA, 90031
# 3         17900 SHERMAN WAY, LOS ANGELES, CA, 91335
# 4          8142 PERSHING DR, LOS ANGELES, CA, 90293
# 5        1431 N HOBART BLVD, LOS ANGELES, CA, 90027
# 6   114 S NEW HAMPSHIRE AVE, LOS ANGELES, CA, 90004
# 7          1342 S ELWOOD ST, LOS ANGELES, CA, 90021
# 8            1201 W 39TH PL, LOS ANGELES, CA, 90037
# 9          345 COLUMBIA AVE, LOS ANGELES, CA, 90017
# 10                         GRAMERCY PL and GAGE AVE
#
#                             neighborhood council_district  reports  \
# 1         WILSHIRE CENTER - KOREATOWN NC             10.0      115
# 2                     LINCOLN HEIGHTS NC              1.0       78
# 3                              RESEDA NC              4.0       78
# 4                   WESTCHESTER/PLAYA NC             11.0       76
# 5                      EAST HOLLYWOOD NC             13.0       73
# 6         WILSHIRE CENTER - KOREATOWN NC             10.0       73
# 7                   DOWNTOWN LOS ANGELES             14.0       65
# 8     EMPOWERMENT CONGRESS NORTH AREA NC              8.0       63
# 9                      WESTLAKE NORTH NC              1.0       63
# 10  EMPOWERMENT CONGRESS CENTRAL AREA NC              8.0       60
#
#     median_gap_days                                    why_interesting
# 1               0.4  WENT QUIET Apr 17 after heavy activity - inter...
# 2               1.0  encampment-adjacent (LSD); refills every 1-2 days
# 3               1.3                             refills every 1-2 days
# 4               0.0                              sub-daily report gaps
# 5               1.1                             refills every 1-2 days
# 6               0.9                              sub-daily report gaps
# 7               0.5   encampment-adjacent (LSD); sub-daily report gaps
# 8               2.0                             refills every 1-2 days
# 9               1.4        32% gone-on-arrival; refills every 1-2 days
# 10              2.0                             refills every 1-2 days

# %% [markdown]
# Ten sites, three archetypes (per notebook 05): encampment-adjacent anchors (4th & New Hampshire, 350 N Avenue 21, Elwood St, Lankershim), resident/commercial refill corners (114 S New Hampshire, W 39th Pl, Columbia Ave, Gramercy & Gage), and the standing puzzles — Pershing Dr (Westchester: 76 reports *in a low-dumping district*, burst re-reporting) and 17900 Sherman Way (the Reseda corridor anchor, doubling as a Valley target below).
#
# **And one discovery made while assembling this list: the citywide #1 site went dark.** 4th St & New Hampshire Ave logged 115 reports between Jan 1 and Apr 17 (27, 34, 35 by month, ~one report every 1.5 days) — then **zero reports for the final 2.5 months** of the period. It is 100% LSD-serviced, so an encampment resolution (Inside Safe operation? posted CARE+ schedule change? physical site alteration?) is the leading hypothesis. **This makes it the single highest-value visit on the list**: if something at that corner *worked*, we want to know what it was — and whether the demand migrated to a nearby corner (114 S New Hampshire, 400m south, remained active through June).

# %% [markdown]
# ### Map: where the citywide top 10 sit
#
# *New tool note:* **Folium** wraps Leaflet.js, the standard web-mapping library, so a Python one-liner produces an interactive, zoomable map embedded right in the notebook — where matplotlib gave us static overview maps (notebook 05), Folium lets us *inspect individual sites* (click a marker for its selection rationale). Same GeoPandas data underneath; this is presentation, not new analysis.

# %%
import folium

def site_popup(r, why_col):
    return folium.Popup(
        f"<b>{r['address']}</b><br>{r['neighborhood']}<br>"
        f"reports: {r['reports']} | median gap: {r['median_gap_days']} d<br>"
        f"<i>{r[why_col]}</i>", max_width=300)

m1 = folium.Map(location=[34.04, -118.32], zoom_start=10, tiles="cartodbpositron")
for _, r in A.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=9, color="crimson", weight=2,
                        fill=True, fill_opacity=0.85,
                        popup=site_popup(r, "why_interesting")).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c45785a8286b6ef0d6aca3466ffbdf75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c45785a8286b6ef0d6aca3466ffbdf75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c45785a8286b6ef0d6aca3466ffbdf75 = L.map(
#                 &quot;map_c45785a8286b6ef0d6aca3466ffbdf75&quot;,
#                 {
#                     center: [34.04, -118.32],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24b7ad49e42d16187c567aaeb0b0e17d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24b7ad49e42d16187c567aaeb0b0e17d.addTo(map_c45785a8286b6ef0d6aca3466ffbdf75);
#
#
#             var circle_marker_5f7b5c2fc035f9115f0a2a946adfb573 = L.circleMarker(
#                 [34.067372919723596, -118.29294677907863],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c45785a8286b6ef0d6aca3466ffbdf75);
#
#
#         var popup_c6fea2b8198f13651bc548bd2ed9e648 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_73f4dbd44042b915389069a085c5a627 = $(`&lt;div id=&quot;html_73f4dbd44042b915389069a085c5a627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;4TH ST and NEW HAMPSHIRE AVE&lt;/b&gt;&lt;br&gt;WILSHIRE CENTER - KOREATOWN NC&lt;br&gt;reports: 115 | median gap: 0.4 d&lt;br&gt;&lt;i&gt;WENT QUIET Apr 17 after heavy activity - intervention?; encampment-adjacent (LSD); sub-daily report gaps&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_c6fea2b8198f13651bc548bd2ed9e648.setContent(html_73f4dbd44042b915389069a085c5a627);
#
#
#
#         circle_marker_5f7b5c2fc035f9115f0a2a946adfb573.bindPopup(popup_c6fea2b8198f13651bc548bd2ed9e648)
#         ;
#
#
#
#
#             var circle_marker_b3e8b6f0e165aa80111b5e01ba2bf493 = L.circleMarker(
#                 [34.078887, -118.22247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c45785a8286b6ef0d6aca3466ffbdf75);
#
#
#         var popup_d6d0b2f75e28b666f34d209d0dccbed6 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_47ed065d7bb8092f86d2aaa502431143 = $(`&lt;div id=&quot;html_47ed065d7bb8092f86d2aaa502431143&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;350 N AVENUE 21, LOS ANGELES, CA, 90031&lt;/b&gt;&lt;br&gt;LINCOLN HEIGHTS NC&lt;br&gt;reports: 78 | median gap: 1.0 d&lt;br&gt;&lt;i&gt;encampment-adjacent (LSD); refills every 1-2 days&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d6d0b2f75e28b666f34d209d0dccbed6.setContent(html_47ed065d7bb8092f86d2aaa502431143);
#
#
#
#         circle_marker_b3e8b6f0e165aa80111b5e01ba2bf493.bindPopup(popup_d6d0b2f75e28b666f34d209d0dccbed6)
#         ;
#
#
#
#
#             var circle_marker_ec92272e60859f1284b451f08c062485 = L.circleMarker(
#                 [34.200925052552805, -118.52286867799768],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c45785a8286b6ef0d6aca3466ffbdf75);
#
#
#         var popup_bdf3e949da5e0705ea9f951fcdb7ab49 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });

# %% [markdown]
# **Reading the map:** the top 10 trace the city's chronic-dumping geography, not a random scatter — a central cluster (Koreatown pair, East Hollywood, Westlake, Downtown edge, Lincoln Heights), the South LA corners, and two outliers that earn their place for different reasons: the Reseda corridor anchor (Valley) and the Pershing Dr oddball (coastal Westchester, where chronic dumping "shouldn't" be). The two New Hampshire Ave markers 400m apart are the natural experiment: one went silent in April, one didn't.

# %% [markdown]
# ## B. San Fernando Valley field targets — revisit sites for the project's duration

# %%
valley_places = g[g["neigh"].notna()].groupby("place").size()
vp = place_stats.loc[place_stats.index.isin(valley_places.index)].copy()
vp["neigh"] = g.groupby("place")["neigh"].agg(mode_or_blank)

# top site per neighborhood first (coverage), then fill to 9 by report count
picks = vp.sort_values("reports", ascending=False).groupby("neigh").head(1)
rest = vp.drop(picks.index).nlargest(9 - len(picks), "reports")
B = pd.concat([picks, rest]).sort_values("reports", ascending=False)
B["why_selected"] = B.apply(why, axis=1) + "; " + B["neigh"].map({
    "Van Nuys": "Valley dumping capital",
    "North Hollywood": "encampment-adjacent archetype",
    "Reseda": "Sherman Way corridor",
    "Panorama City": "gone-on-arrival anomaly area",
    "Encino": "chronic pocket inside clean background",
    "Sherman Oaks": "moderate-area top site",
    "Studio City": "clean-area top site (ceiling check)",
})
B = B.reset_index(drop=True).round({"median_gap_days": 1, "lsd_share": 2, "gone_on_arrival": 2})
B.index += 1
B[["address", "neigh", "reports", "median_gap_days", "why_selected"]]
# Out:
#                                         address            neigh  reports  \
# 1     17900 SHERMAN WAY, LOS ANGELES, CA, 91335           Reseda       78
# 2  5767 LANKERSHIM BLVD, LOS ANGELES, CA, 91601  North Hollywood       60
# 3       14102 DELANO ST, LOS ANGELES, CA, 91401         Van Nuys       58
# 4     17808 SHERMAN WAY, LOS ANGELES, CA, 91335           Reseda       53
# 5     13036 SHERMAN WAY, LOS ANGELES, CA, 91605  North Hollywood       46
# 6     5130 YARMOUTH AVE, LOS ANGELES, CA, 91316           Encino       37
# 7    9404 VAN NUYS BLVD, LOS ANGELES, CA, 91402    Panorama City       35
# 8      14359 ADDISON ST, LOS ANGELES, CA, 91423     Sherman Oaks       26
# 9          4176 ARCH DR, LOS ANGELES, CA, 91604      Studio City       22
#
#    median_gap_days                                       why_selected
# 1              1.3       refills every 1-2 days; Sherman Way corridor
# 2              1.6  encampment-adjacent (LSD); refills every 1-2 d...
# 3              2.1  31% gone-on-arrival; refills every 1-2 days; V...
# 4              2.8     high-volume chronic site; Sherman Way corridor
# 5              2.5  encampment-adjacent (LSD); encampment-adjacent...
# 6              3.5  high-volume chronic site; chronic pocket insid...
# 7              5.5  high-volume chronic site; gone-on-arrival anom...
# 8              3.4   high-volume chronic site; moderate-area top site
# 9              6.3  high-volume chronic site; clean-area top site ...

# %% [markdown]
# Selection rule: the top site in *each* of the seven neighborhoods (coverage — including Studio City's modest ceiling, which calibrates what "clean-area worst" looks like), then the remaining slots filled by report count (which adds the second Reseda corridor block and Van Nuys's Erwin St). These are deliberately *revisitable*: all are within a short drive of each other, so a single loop can sample the full range from 78-report chronic to 22-report clean-area-max.

# %% [markdown]
# ### Map: the Valley selections in context
#
# Markers are the nine investigation sites; shaded polygons are the seven calibrated neighborhoods (NC boundaries). Not a route — the field guide handles navigation.

# %%
valley_ncs = [nc for ncs in NEIGH.values() for nc in ncs]
bounds = gpd.read_file("../../shared/datasets/raw/la_neighborhood_councils.geojson")
bounds["NAME"] = bounds["NAME"].str.upper().str.strip()
valley_poly = bounds[bounds["NAME"].isin(valley_ncs)]

m2 = folium.Map(location=[34.20, -118.45], zoom_start=11, tiles="cartodbpositron")
folium.GeoJson(valley_poly.to_json(), name="calibrated NCs",
               style_function=lambda f: {"color": "#666", "weight": 1.5,
                                         "fillColor": "#bbb", "fillOpacity": 0.15},
               tooltip=folium.GeoJsonTooltip(fields=["NAME"])).add_to(m2)
for _, r in B.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=8, color="royalblue", weight=2,
                        fill=True, fill_opacity=0.85,
                        popup=site_popup(r, "why_selected")).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ebe7df919ac940a581481c6bb60f168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ebe7df919ac940a581481c6bb60f168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ebe7df919ac940a581481c6bb60f168 = L.map(
#                 &quot;map_4ebe7df919ac940a581481c6bb60f168&quot;,
#                 {
#                     center: [34.2, -118.45],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1825c1e292026e0c710fef59e1f48f7f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1825c1e292026e0c710fef59e1f48f7f.addTo(map_4ebe7df919ac940a581481c6bb60f168);
#
#
#         function geo_json_39c13b564c0cb399a606442040990afe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#666&quot;, &quot;fillColor&quot;: &quot;#bbb&quot;, &quot;fillOpacity&quot;: 0.15, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_39c13b564c0cb399a606442040990afe_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_39c13b564c0cb399a606442040990afe = L.geoJson(null, {
#                 onEachFeature: geo_json_39c13b564c0cb399a606442040990afe_onEachFeature,
#
#                 style: geo_json_39c13b564c0cb399a606442040990afe_styler,
#             ...{
# }
#         });
#
#         function geo_json_39c13b564c0cb399a606442040990afe_add (data) {
#             geo_json_39c13b564c0cb399a606442040990afe
#                 .addData(data);
#         }
#             geo_json_39c13b564c0cb399a606442040990afe_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.54049284974853, 34.12941254664266], [-118.5403898891326, 34.12947019547018], [-118.54038015002061, 34.129475649169876], [-118.54030112202847, 34.129515499046235], [-118.5401631561585, 34.12959009087703], [-118.54013648145792, 34.129604512156206], [-118.53996815239294, 34.12963411812144], [-118.53990338483949, 34.12964195876], [-118.53970894452647, 34.12966549640804], [-118.53957858693451, 34.12969149469418], [-118.539496151299, 34.12971728436631], [-118.53942035693734, 34.12975198133863], [-118.53938914848221, 34.12977752248057], [-118.5393596029321, 34.1298095986908], [-118.53935087522765, 34.129825810412704], [-118.539335129636, 34.12985506812079], [-118.53931882804021, 34.12989292001108], [-118.53930752165041, 34.12992869319256], [-118.53930162301685, 34.12995357144132], [-118.5392994531033, 34.12996272186597], [-118.53929636702989, 34.129995385009906], [-118.53929658850072, 34.13002971206948], [-118.53931207043044, 34.13012307438837], [-118.53932722504179, 34.130170070013115], [-118.53934734129435, 34.130214986176114], [-118.5393691078318, 34.13025472913129], [-118.53938909475619, 34.13028178089112], [-118.53941403909486, 34.13030878618303], [-118.53946071910535, 34.13037006578764], [-118.53951245629793, 34.130452625359176], [-118.5395341959118, 34.130492038440934], [-118.53955095038089, 34.13052938219197], [-118.5395762357504, 34.13060382421429], [-118.53958966433086, 34.13067965434672], [-118.53959337292945, 34.13070061489129], [-118.53960722541316, 34.1307981054025], [-118.53960888921706, 34.13080510656942], [-118.53963607119645, 34.13091923053972], [-118.53963461711054, 34.13094773750716], [-118.53961354437502, 34.13100930058096], [-118.53958579814467, 34.13106371445562], [-118.53956444861768, 34.13108509518614], [-118.53953982633982, 34.13110651666598], [-118.5395052442577, 34.1311286344106], [-118.53947066480676, 34.131145283374295], [-118.5394014563579, 34.13117410172633], [-118.5393272797919, 34.13119812886818], [-118.53928933225794, 34.131209293395976], [-118.53924510679771, 34.13121781825355], [-118.53920353092364, 34.13122583362391], [-118.53915894987229, 34.131231168574296], [-118.53909618285962, 34.13123522599286], [-118.539

# %% [markdown]
# **Reading the map:** the selection logic is visible geographically. The three Sherman Way markers form a west–east line across the Valley — same street, two different neighborhoods and service contexts (Reseda pair vs the LSD-serviced NoHo-NE site 5km east). The Van Nuys / Panorama City pair sits on the north–south Van Nuys Blvd axis. The southern tier (Encino, Sherman Oaks, Studio City) hugs the Ventura corridor — each is its neighborhood's *worst* site, chosen so a single day covers the full range from 78-report chronic to a clean area's 22-report ceiling. Every site is the top site of its NC (coverage rule), so the map is also a picture of each neighborhood's maximum.

# %% [markdown]
# ## C. Clean comparison sites

# %%
nc_table = op.groupby("NCName").size().rename("op_demand").to_frame()
nc_table["dumping"] = g.groupby("NCName").size()
nc_table = nc_table.fillna(0)
nc_table["dump_share_%"] = (nc_table["dumping"] / nc_table["op_demand"] * 100).round(1)
nc_places = g.groupby("NCName")["place"].apply(lambda s: (s.value_counts() >= 25).sum())
nc_table["chronic_places_25+"] = nc_places
clean = nc_table[nc_table["op_demand"] >= 4000].sort_values("dump_share_%").head(10)
clean
# Out:
#                                  op_demand  dumping  dump_share_%  \
# NCName
# PORTER RANCH NC                       4005      210           5.2
# BEL AIR-BEVERLY CREST NC              5835      319           5.5
# WESTLAKE SOUTH NC                    10808     1071           9.9
# GRANADA HILLS NORTH NC                4908      571          11.6
# WOODLAND HILLS-WARNER CENTER NC      13376     1677          12.5
# NORTHRIDGE WEST NC                    4228      618          14.6
# WEST HILLS NC                         8631     1310          15.2
# DOWNTOWN LOS ANGELES                 20996     3204          15.3
# GRANADA HILLS SOUTH NC                8064     1280          15.9
# NORTHRIDGE EAST NC                    5398      859          15.9
#
#                                  chronic_places_25+
# NCName
# PORTER RANCH NC                                   0
# BEL AIR-BEVERLY CREST NC                          0
# WESTLAKE SOUTH NC                                 2
# GRANADA HILLS NORTH NC                            1
# WOODLAND HILLS-WARNER CENTER NC                   4
# NORTHRIDGE WEST NC                                0
# WEST HILLS NC                                     0
# DOWNTOWN LOS ANGELES                             13
# GRANADA HILLS SOUTH NC                            0
# NORTHRIDGE EAST NC                                0

# %% [markdown]
# Chosen comparison sites (share read *together with* chronic-place count, per the DTLA warning — Downtown's low share is a denominator artifact and it is excluded):
#
# 1. **Studio City — Ventura Blvd (Laurel Canyon ↔ Coldwater)**: 0.59x share, zero chronic places, *inside* the study area — the primary control, one boundary away from Van Nuys.
# 2. **Woodland Hills–Warner Center**: a major commercial center with high overall 311 engagement (13.4K cases — people report plenty) yet only a 12.5% dumping share. High civic voice + low dumping = the cleanest fair comparison for commercial corridors.
# 3. **Porter Ranch**: the citywide minimum (5.2%) among engaged NCs — master-planned suburb; useful as the "what does near-zero look like" anchor, with the caveat that its built form (HOA, no alleys, low renter share) explains as much as any city service does.
# 4. **Granada Hills North (11.6%)**: single-family Valley fabric demographically closer to Reseda/Northridge than Porter Ranch — a fairer "ordinary but clean" Valley control.
# 5. **Sherman Oaks — Ventura corridor**: 0.82x, low intensity; the *gradient* case — same boulevard, changing conditions, 2km from Van Nuys's worst blocks.
#
# Why these "perform well," per the data: all combine below-mix dumping share, few or no chronic places, *and* healthy overall 311 usage (so quiet-≠-clean bias is partially controlled — these communities demonstrably do report things). What the data *cannot* say is why: built form, income, alley presence, enforcement, private hauling. That's exactly what visiting them alongside the chronic sites is for.

# %% [markdown]
# ### Map: clean comparison areas
#
# Green polygons — comparison *areas*, not point sites (their value is the absence of chronic points). Click for the selection rationale.

# %%
CLEAN_AREAS = {
    "STUDIO CITY NC": "Primary control: 0.59x citywide mix, ZERO chronic 25+ places, adjacent to Van Nuys",
    "SHERMAN OAKS NC": "Gradient case: 0.82x, low intensity, same boulevard as Studio City, 2km from Van Nuys's worst",
    "WOODLAND HILLS-WARNER CENTER NC": "Commercial-corridor control: heavy 311 reporters (13.4K cases) yet only 12.5% dumping share",
    "GRANADA HILLS NORTH NC": "Ordinary-but-clean single-family Valley control (11.6%), demographically closer to Reseda",
    "PORTER RANCH NC": "Near-zero anchor: 5.2% share, citywide minimum among engaged NCs; built form explains much",
}
clean_poly = bounds[bounds["NAME"].isin(CLEAN_AREAS)].copy()
assert len(clean_poly) == 5
clean_poly["why"] = clean_poly["NAME"].map(CLEAN_AREAS)

m3 = folium.Map(location=[34.22, -118.50], zoom_start=10, tiles="cartodbpositron")
folium.GeoJson(clean_poly.to_json(),
               style_function=lambda f: {"color": "seagreen", "weight": 2,
                                         "fillColor": "seagreen", "fillOpacity": 0.25},
               tooltip=folium.GeoJsonTooltip(fields=["NAME", "why"])).add_to(m3)
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfac44cb07ab7c5909e08f2e79f2612c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfac44cb07ab7c5909e08f2e79f2612c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfac44cb07ab7c5909e08f2e79f2612c = L.map(
#                 &quot;map_dfac44cb07ab7c5909e08f2e79f2612c&quot;,
#                 {
#                     center: [34.22, -118.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d1a39a62d88e4976c8ab7c47cecdd19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d1a39a62d88e4976c8ab7c47cecdd19.addTo(map_dfac44cb07ab7c5909e08f2e79f2612c);
#
#
#         function geo_json_04b26916d9a529171b9fe51d6e629474_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.25, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_04b26916d9a529171b9fe51d6e629474_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_04b26916d9a529171b9fe51d6e629474 = L.geoJson(null, {
#                 onEachFeature: geo_json_04b26916d9a529171b9fe51d6e629474_onEachFeature,
#
#                 style: geo_json_04b26916d9a529171b9fe51d6e629474_styler,
#             ...{
# }
#         });
#
#         function geo_json_04b26916d9a529171b9fe51d6e629474_add (data) {
#             geo_json_04b26916d9a529171b9fe51d6e629474
#                 .addData(data);
#         }
#             geo_json_04b26916d9a529171b9fe51d6e629474_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.53657263158097, 34.2932936636314], [-118.53630557473903, 34.2930343196201], [-118.53612766164456, 34.29286154324231], [-118.5361269752028, 34.2928608764348], [-118.53595558183156, 34.29269443223004], [-118.53572123611158, 34.29246685408451], [-118.53551305688511, 34.29229717135624], [-118.53539260267577, 34.29219898950352], [-118.53477609492815, 34.29169646364211], [-118.53462312182887, 34.29157179485374], [-118.53455190127099, 34.291496634788224], [-118.53435892705883, 34.29129298587777], [-118.5343557566924, 34.29128964071846], [-118.53406395795125, 34.29098169784015], [-118.53333485929336, 34.29021224830201], [-118.53332604940847, 34.29020294982271], [-118.5332940053532, 34.29016913252948], [-118.5329516814821, 34.289702745193296], [-118.5329469402461, 34.28969628486848], [-118.53280921475654, 34.289508643378134], [-118.53217204754014, 34.288640535916144], [-118.53201868114499, 34.288431577678466], [-118.53159457757256, 34.28785374279281], [-118.53113837909876, 34.28745585897186], [-118.53041487356037, 34.28682482190809], [-118.53008199409821, 34.286534483490136], [-118.52927443121062, 34.28583012451196], [-118.52899963535923, 34.28559044478636], [-118.52832602299259, 34.28500291392545], [-118.52815940045275, 34.28424182383563], [-118.52804320725942, 34.28371107320333], [-118.5278677878329, 34.282909774411856], [-118.5278510751188, 34.2828334244076], [-118.52779250619288, 34.28256581338789], [-118.52773370441432, 34.282051663033236], [-118.52763023110381, 34.28114690033895], [-118.52757906610964, 34.280699513715334], [-118.52743784494798, 34.280316444135565], [-118.52709977871434, 34.279399410238575], [-118.52697109472005, 34.27905033861281], [-118.52695915466799, 34.278784139821504], [-118.52692773924983, 34.278181314965444], [-118.52678648052377, 34.27821157410819], [-118.52661779272154, 34.27823326060773], [-118.52633652089038, 34.27824925351762], [-118.52599238263585, 34.27826998421456], [-118.52565310237352, 34.27827351845953], [-118.52465005354074, 34.27826790747985], [-118.52443621494567, 34.27826575774778], [-118.52440415718407, 34.27826543499701], [-118.52249955897838, 34.27824626781398], [-118.52228636890231, 34.2782441205

# %% [markdown]
# All five controls combine below-mix dumping share with *healthy overall 311 usage* — communities that demonstrably report things (partially controlling quiet-≠-clean bias). Three sit in the Valley on purpose: comparisons work best against familiar territory.
#
# ### Map: the full investigation picture

# %%
m4 = folium.Map(location=[34.10, -118.40], zoom_start=10, tiles="cartodbpositron")
folium.GeoJson(clean_poly.to_json(),
               style_function=lambda f: {"color": "seagreen", "weight": 2,
                                         "fillColor": "seagreen", "fillOpacity": 0.22},
               tooltip=folium.GeoJsonTooltip(fields=["NAME", "why"])).add_to(m4)
for _, r in A.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=9, color="crimson", weight=2,
                        fill=True, fill_opacity=0.85,
                        popup=site_popup(r, "why_interesting")).add_to(m4)
for _, r in B.iterrows():
    folium.CircleMarker([r["lat"], r["lon"]], radius=7, color="royalblue", weight=2,
                        fill=True, fill_opacity=0.85,
                        popup=site_popup(r, "why_selected")).add_to(m4)

legend = '''<div style="position: fixed; bottom: 30px; left: 30px; z-index: 9999;
     background: white; padding: 8px 12px; border: 1px solid #999; border-radius: 4px;
     font-size: 13px; line-height: 1.6;">
<b>Investigation program</b><br>
<span style="color: crimson;">&#9679;</span> citywide chronic hotspot (A)<br>
<span style="color: royalblue;">&#9679;</span> Valley investigation site (B)<br>
<span style="color: seagreen;">&#9632;</span> clean comparison area (C)</div>'''
m4.get_root().html.add_child(folium.Element(legend))
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_459a805006891f7cb639f9b854930b00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 30px; left: 30px; z-index: 9999;
#      background: white; padding: 8px 12px; border: 1px solid #999; border-radius: 4px;
#      font-size: 13px; line-height: 1.6;&quot;&gt;
# &lt;b&gt;Investigation program&lt;/b&gt;&lt;br&gt;
# &lt;span style=&quot;color: crimson;&quot;&gt;&amp;#9679;&lt;/span&gt; citywide chronic hotspot (A)&lt;br&gt;
# &lt;span style=&quot;color: royalblue;&quot;&gt;&amp;#9679;&lt;/span&gt; Valley investigation site (B)&lt;br&gt;
# &lt;span style=&quot;color: seagreen;&quot;&gt;&amp;#9632;&lt;/span&gt; clean comparison area (C)&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_459a805006891f7cb639f9b854930b00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_459a805006891f7cb639f9b854930b00 = L.map(
#                 &quot;map_459a805006891f7cb639f9b854930b00&quot;,
#                 {
#                     center: [34.1, -118.4],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d4797f8aaf75fe7eac1f6e82de3b62c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d4797f8aaf75fe7eac1f6e82de3b62c.addTo(map_459a805006891f7cb639f9b854930b00);
#
#
#         function geo_json_6210805d4d0280a8a52450ec09ca333e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;seagreen&quot;, &quot;fillColor&quot;: &quot;seagreen&quot;, &quot;fillOpacity&quot;: 0.22, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_6210805d4d0280a8a52450ec09ca333e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6210805d4d0280a8a52450ec09ca333e = L.geoJson(null, {
#                 onEachFeature: geo_json_6210805d4d0280a8a52450ec09ca333e_onEachFeature,
#
#                 style: geo_json_6210805d4d0280a8a52450ec09ca333e_styler,
#             ...{
# }
#         });
#
#         function geo_json_6210805d4d0280a8a52450ec09ca333e_add (data) {
#             geo_json_6210805d4d0280a8a52450ec09ca333e
#                 .addData(data);
#         }
#             geo_json_6210805d4d0280a8a52450ec09ca333e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.53657263158097, 34.2932936636314], [-118.53630557473903, 34.2930343196201], [-118.53612766164456, 34.29286154324231], [-118.5361269752028, 34.2928608764348], [-118.53595558183156, 34.29269443223004], [-118.53572123611158, 34.29246685408451], [-118.53551305688511, 34.29229717135624], [-118.53539260267577, 34.29219898950352], [-118.53477609492815, 34.29169646364211], [-118.53462312182887, 34.29157179485374], [-118.53455190127099, 34.291496634788224], [-118.53435892705883, 34.29129298587777], [-118.5343557566924, 34.29128964071846], [-118.53406395795125, 34.29098169784015], [-118.53333485929336, 34.29021224830201], [-118.53332604940847, 34.29020294982271], [-118.5332940053532, 34.29016913252948], [-118.5329516814821, 34.289702745193296], [-118.5329469402461, 34.28969628486848], [-118.53280921475654, 34.289508643378134], [-118.53217204754014, 34.288640535916144], [-118.53201868114499, 34.288431577678466], [-118.53159457757256, 34.28785374279281], [-118.53113837909876, 34.28745585897186], [-118.53041487356037, 34.28682482190809], [-118.53008199409821, 34.286534483490136], [-118.52927443121062, 34.28583012451196], [-118.52899963535923, 34.28559044478636], [-118.52832602299259, 34.28500291392545], [-118.52815940045275, 34.28424182383563], [-118.52804320725942, 34.28371107320333], [-118.5278677878329, 34.282909774411856], [-118.5278510751188, 34.2828334244076], [-118.52779250619288, 34.28256581338789], [-118.52773370441432, 34.282051663033236], [-118.52763023110381, 34.28114690033895], [-118.52757906610964, 34.280699513715334], [-118.52743784494798, 34.

# %% [markdown]
# **Reading the map:** the program's design shows up as structure — red hotspots ring the central city and dot the Valley; blue sites cluster where we can revisit cheaply and know the terrain; green controls sit adjacent to the worst blue areas, so every comparison is a short drive, not a demographic leap. The one deliberate outlier (Pershing Dr, bottom-left) is the "chronic site where none should exist" probe.

# %%
A_out = A.assign(section="A_citywide")
B_out = (B.drop(columns=["neighborhood"])
           .rename(columns={"neigh": "neighborhood", "why_selected": "why_interesting"})
           .assign(section="B_valley"))
program = pd.concat([
    A_out[["section", "address", "neighborhood", "council_district", "reports",
           "median_gap_days", "lsd_share", "gone_on_arrival", "lat", "lon", "why_interesting"]],
    B_out[["section", "address", "neighborhood", "reports",
           "median_gap_days", "lsd_share", "gone_on_arrival", "lat", "lon", "why_interesting"]],
])
program.to_csv("../data/processed/field_program_nb06.csv", index=False)
print(f"saved field program: {len(program)} target sites -> data/processed/field_program_nb06.csv")
print("(clean comparison sites are corridors/areas, not points - listed in markdown above)")
# Out:
# saved field program: 19 target sites -> data/processed/field_program_nb06.csv
# (clean comparison sites are corridors/areas, not points - listed in markdown above)
